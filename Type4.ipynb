# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

X_train = pd.read_csv('data/input/standardized_X_train.csv', index_col=0)
y_train = pd.read_csv('data/input/y_log_train.csv', index_col=0)

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error

def kfold_mse(X, y, model, k=10):
    kf = KFold(n_splits=k)
    mses = []
    for i, (train_idx, val_idx) in enumerate(kf.split(X, y)):
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
        model.fit(X_train, y_train['sales']) # Avoid deprecation warning
        y_pred = model.predict(X_val)
        mses.append(mean_squared_error(np.exp(y_pred), np.exp(y_val['sales'])))
    return mses

# %%
from sklearn.ensemble import RandomForestRegressor

ccp_alphas = [0.0, 0.01, 0.05]
min_samples_leafs = [1, 3, 5, 10]
max_depths = [None, 3, 5, 10]

best_mses = []
best_avg_score = 1e9
best_ccp_alpha = None
best_depth = None
best_min_samples_leaf = None
for ccp_alpha in ccp_alphas:
    for depth in max_depths:
        for min_samples_leaf in min_samples_leafs:
            model = RandomForestRegressor(ccp_alpha=ccp_alpha, max_depth=depth, min_samples_leaf=min_samples_leaf, random_state=42, min_samples_split=0.01, max_features='sqrt', n_estimators=1000)
            mses = kfold_mse(X_train, y_train, model)
            if np.mean(mses) < best_avg_score:
                best_avg_score = np.mean(mses)
                best_ccp_alpha = ccp_alpha
                best_depth = depth
                best_min_samples_leaf = min_samples_leaf
                best_mses = mses
            print(f'ccp_alpha: {ccp_alpha}, max_depth: {depth}, min_samples_leaf: {min_samples_leaf}, avg_mse: {np.mean(mses)}')
# Out:
# ccp_alpha: 0.0, max_depth: None, min_samples_leaf: 1, avg_mse: 449.795205911368
# ccp_alpha: 0.0, max_depth: None, min_samples_leaf: 3, avg_mse: 466.5833851594368
# ccp_alpha: 0.0, max_depth: None, min_samples_leaf: 5, avg_mse: 481.0847154287885
# ccp_alpha: 0.0, max_depth: None, min_samples_leaf: 10, avg_mse: 511.99738949145586
# ccp_alpha: 0.0, max_depth: 3, min_samples_leaf: 1, avg_mse: 700.035323276167
# ccp_alpha: 0.0, max_depth: 3, min_samples_leaf: 3, avg_mse: 699.8218274392399
# ccp_alpha: 0.0, max_depth: 3, min_samples_leaf: 5, avg_mse: 699.7900774932552
# ccp_alpha: 0.0, max_depth: 3, min_samples_leaf: 10, avg_mse: 700.2282731589246
# ccp_alpha: 0.0, max_depth: 5, min_samples_leaf: 1, avg_mse: 635.4192802973595
# ccp_alpha: 0.0, max_depth: 5, min_samples_leaf: 3, avg_mse: 635.2475965855176
# ccp_alpha: 0.0, max_depth: 5, min_samples_leaf: 5, avg_mse: 635.2435440509715
# ccp_alpha: 0.0, max_depth: 5, min_samples_leaf: 10, avg_mse: 636.9351024270994
# ccp_alpha: 0.0, max_depth: 10, min_samples_leaf: 1, avg_mse: 529.1155295066768
# ccp_alpha: 0.0, max_depth: 10, min_samples_leaf: 3, avg_mse: 531.4100461033652
# ccp_alpha: 0.0, max_depth: 10, min_samples_leaf: 5, avg_mse: 534.284610499445
# ccp_alpha: 0.0, max_depth: 10, min_samples_leaf: 10, avg_mse: 543.9202921810213
# ccp_alpha: 0.01, max_depth: None, min_samples_leaf: 1, avg_mse: 551.401920940941
# ccp_alpha: 0.01, max_depth: None, min_samples_leaf: 3, avg_mse: 554.2617361984173
# ccp_alpha: 0.01, max_depth: None, min_samples_leaf: 5, avg_mse: 556.381561227673
# ccp_alpha: 0.01, max_depth: None, min_samples_leaf: 10, avg_mse: 564.2133381000435
# ccp_alpha: 0.01, max_depth: 3, min_samples_leaf: 1, avg_mse: 701.2656210292199
# ccp_alpha: 0.01, max_depth: 3, min_samples_leaf: 3, avg_mse: 701.104564037688
# ccp_alpha: 0.01, max_depth: 3, min_samples_leaf: 5, avg_mse: 701.0638132754159
# ccp_alpha: 0.01, max_depth: 3, min_samples_leaf: 10, avg_mse: 701.488824550823
# ccp_alpha: 0.01, max_depth: 5, min_samples_leaf: 1, avg_mse: 640.7645416085321
# ccp_alpha: 0.01, max_depth: 5, min_samples_leaf: 3, avg_mse: 640.6935598106215
# ccp_alpha: 0.01, max_depth: 5, min_samples_leaf: 5, avg_mse: 640.7576525140082
# ccp_alpha: 0.01, max_depth: 5, min_samples_leaf: 10, avg_mse: 642.3880888840031
# ccp_alpha: 0.01, max_depth: 10, min_samples_leaf: 1, avg_mse: 567.5834673573929
# ccp_alpha: 0.01, max_depth: 10, min_samples_leaf: 3, avg_mse: 568.4368192022055
# ccp_alpha: 0.01, max_depth: 10, min_samples_leaf: 5, avg_mse: 570.1578731769638
# ccp_alpha: 0.01, max_depth: 10, min_samples_leaf: 10, avg_mse: 575.1307276820621
# ccp_alpha: 0.05, max_depth: None, min_samples_leaf: 1, avg_mse: 655.8877580386032
# ccp_alpha: 0.05, max_depth: None, min_samples_leaf: 3, avg_mse: 656.5612782342673
# ccp_alpha: 0.05, max_depth: None, min_samples_leaf: 5, avg_mse: 656.2058011827366
# ccp_alpha: 0.05, max_depth: None, min_samples_leaf: 10, avg_mse: 657.3463839627913
# ccp_alpha: 0.05, max_depth: 3, min_samples_leaf: 1, avg_mse: 712.1156770176302
# ccp_alpha: 0.05, max_depth: 3, min_samples_leaf: 3, avg_mse: 711.8905336557084
# ccp_alpha: 0.05, max_depth: 3, min_samples_leaf: 5, avg_mse: 711.8783820525964
# ccp_alpha: 0.05, max_depth: 3, min_samples_leaf: 10, avg_mse: 712.2706771463838
# ccp_alpha: 0.05, max_depth: 5, min_samples_leaf: 1, avg_mse: 673.8988989151997
# ccp_alpha: 0.05, max_depth: 5, min_samples_leaf: 3, avg_mse: 673.7438173905929
# ccp_alpha: 0.05, max_depth: 5, min_samples_leaf: 5, avg_mse: 673.9574190006961
# ccp_alpha: 0.05, max_depth: 5, min_samples_leaf: 10, avg_mse: 674.4462240206967
# ccp_alpha: 0.05, max_depth: 10, min_samples_leaf: 1, avg_mse: 656.5945558937362
# ccp_alpha: 0.05, max_depth: 10, min_samples_leaf: 3, avg_mse: 655.8069906907333
# ccp_alpha: 0.05, max_depth: 10, min_samples_leaf: 5, avg_mse: 656.3451874186428
# ccp_alpha: 0.05, max_depth: 10, min_samples_leaf: 10, avg_mse: 656.9297694514793

# %%
cv_df = pd.DataFrame(best_mses, columns=['Cross-Validation MSE'])
cv_df
# Out:
#    Cross-Validation MSE
# 0            474.549089
# 1            234.055917
# 2            482.996077
# 3            327.428166
# 4            447.355815
# 5            182.829120
# 6            720.636845
# 7            424.239794
# 8           1085.242167
# 9            118.619068

# %%
print(f'best ccp_alpha: {best_ccp_alpha}, best max_depth: {best_depth}, best min_samples_leaf: {best_min_samples_leaf}, best avg_mse: {np.mean(best_mses)}')
# Out:
# best ccp_alpha: 0.0, best max_depth: None, best min_samples_leaf: 1, best avg_mse: 449.795205911368

# %%
cv_df.to_csv('data/output/cv/rf_sta_log.csv')

# %%
from sklearn.ensemble import GradientBoostingRegressor

learning_rates = [0.01, 0.1, 0.5, 1]
max_depths = [None, 3, 5, 10]
min_samples_leafs = [1, 3, 5, 10]

best_mses = []
best_avg_score = 1e9
best_lr = None
best_depth = None
best_msl = None
for lr in learning_rates:
    for depth in max_depths:
        for min_samples_leaf in min_samples_leafs:
            model = GradientBoostingRegressor(min_samples_leaf=min_samples_leaf, min_samples_split=0.01, n_estimators=1000, max_features='sqrt', random_state=42, learning_rate=lr, max_depth=depth)
            mses = kfold_mse(X_train, y_train, model)
            if np.mean(mses) < best_avg_score:
                best_avg_score = np.mean(mses)
                best_lr = lr
                best_depth = depth
                best_msl = min_samples_leaf
                best_mses = mses
            print(f'lr: {lr}, max_depth: {depth}, min_samples_leaf: {min_samples_leaf}, avg_mse: {np.mean(mses)}')
# Out:
# lr: 0.01, max_depth: None, min_samples_leaf: 1, avg_mse: 323.2214177878385
# lr: 0.01, max_depth: None, min_samples_leaf: 3, avg_mse: 298.9954062970762
# lr: 0.01, max_depth: None, min_samples_leaf: 5, avg_mse: 297.40998943637226
# lr: 0.01, max_depth: None, min_samples_leaf: 10, avg_mse: 285.74703175057914
# lr: 0.01, max_depth: 3, min_samples_leaf: 1, avg_mse: 398.4550496201102
# lr: 0.01, max_depth: 3, min_samples_leaf: 3, avg_mse: 394.47427734960235
# lr: 0.01, max_depth: 3, min_samples_leaf: 5, avg_mse: 393.21148459321023
# lr: 0.01, max_depth: 3, min_samples_leaf: 10, avg_mse: 394.56382914852117
# lr: 0.01, max_depth: 5, min_samples_leaf: 1, avg_mse: 331.7697252264397
# lr: 0.01, max_depth: 5, min_samples_leaf: 3, avg_mse: 325.2805902442218
# lr: 0.01, max_depth: 5, min_samples_leaf: 5, avg_mse: 326.3353851635758
# lr: 0.01, max_depth: 5, min_samples_leaf: 10, avg_mse: 328.91592193336885
# lr: 0.01, max_depth: 10, min_samples_leaf: 1, avg_mse: 294.0695274172244
# lr: 0.01, max_depth: 10, min_samples_leaf: 3, avg_mse: 280.59285377578294
# lr: 0.01, max_depth: 10, min_samples_leaf: 5, avg_mse: 284.8087864521677
# lr: 0.01, max_depth: 10, min_samples_leaf: 10, avg_mse: 285.60112649457096
# lr: 0.1, max_depth: None, min_samples_leaf: 1, avg_mse: 326.2997150313377
# lr: 0.1, max_depth: None, min_samples_leaf: 3, avg_mse: 299.3332979521539
# lr: 0.1, max_depth: None, min_samples_leaf: 5, avg_mse: 294.3171758475024
# lr: 0.1, max_depth: None, min_samples_leaf: 10, avg_mse: 297.6583314900277
# lr: 0.1, max_depth: 3, min_samples_leaf: 1, avg_mse: 264.94288677934725
# lr: 0.1, max_depth: 3, min_samples_leaf: 3, avg_mse: 258.78482027874225
# lr: 0.1, max_depth: 3, min_samples_leaf: 5, avg_mse: 251.9675307113601
# lr: 0.1, max_depth: 3, min_samples_leaf: 10, avg_mse: 257.5983324495181
# lr: 0.1, max_depth: 5, min_samples_leaf: 1, avg_mse: 257.98890756221476
# lr: 0.1, max_depth: 5, min_samples_leaf: 3, avg_mse: 252.18945625012793
# lr: 0.1, max_depth: 5, min_samples_leaf: 5, avg_mse: 253.4477834916063
# lr: 0.1, max_depth: 5, min_samples_leaf: 10, avg_mse: 245.0310008487545
# lr: 0.1, max_depth: 10, min_samples_leaf: 1, avg_mse: 282.1149377209917
# lr: 0.1, max_depth: 10, min_samples_leaf: 3, avg_mse: 289.8981320137043
# lr: 0.1, max_depth: 10, min_samples_leaf: 5, avg_mse: 263.9628689775726
# lr: 0.1, max_depth: 10, min_samples_leaf: 10, avg_mse: 269.4266750399114
# lr: 0.5, max_depth: None, min_samples_leaf: 1, avg_mse: 354.5058537930911
# lr: 0.5, max_depth: None, min_samples_leaf: 3, avg_mse: 361.4916612608462
# lr: 0.5, max_depth: None, min_samples_leaf: 5, avg_mse: 355.69965078827795
# lr: 0.5, max_depth: None, min_samples_leaf: 10, avg_mse: 351.67466341785837
# lr: 0.5, max_depth: 3, min_samples_leaf: 1, avg_mse: 267.17307296080753
# lr: 0.5, max_depth: 3, min_samples_leaf: 3, avg_mse: 269.0024383669063
# lr: 0.5, max_depth: 3, min_samples_leaf: 5, avg_mse: 270.7398909155794
# lr: 0.5, max_depth: 3, min_samples_leaf: 10, avg_mse: 279.5038566185839
# lr: 0.5, max_depth: 5, min_samples_leaf: 1, avg_mse: 306.3988463671948
# lr: 0.5, max_depth: 5, min_samples_leaf: 3, avg_mse: 276.7564417630056
# lr: 0.5, max_depth: 5, min_samples_leaf: 5, avg_mse: 280.48856703274976
# lr: 0.5, max_depth: 5, min_samples_leaf: 10, avg_mse: 306.5567574147004
# lr: 0.5, max_depth: 10, min_samples_leaf: 1, avg_mse: 323.08690562101674
# lr: 0.5, max_depth: 10, min_samples_leaf: 3, avg_mse: 349.1785578619345
# lr: 0.5, max_depth: 10, min_samples_leaf: 5, avg_mse: 330.4452036387821
# lr: 0.5, max_depth: 10, min_samples_leaf: 10, avg_mse: 329.335232333449
# lr: 1, max_depth: None, min_samples_leaf: 1, avg_mse: 909.2392246341972
# lr: 1, max_depth: None, min_samples_leaf: 3, avg_mse: 923.3647323774827
# lr: 1, max_depth: None, min_samples_leaf: 5, avg_mse: 858.1382296711023
# lr: 1, max_depth: None, min_samples_leaf: 10, avg_mse: 694.3547314323315
# lr: 1, max_depth: 3, min_samples_leaf: 1, avg_mse: 2417.3249308921563
# lr: 1, max_depth: 3, min_samples_leaf: 3, avg_mse: 373.23546625460233
# lr: 1, max_depth: 3, min_samples_leaf: 5, avg_mse: 354.27837039807514
# lr: 1, max_depth: 3, min_samples_leaf: 10, avg_mse: 363.81698451829504
# lr: 1, max_depth: 5, min_samples_leaf: 1, avg_mse: 534.9702571986519
# lr: 1, max_depth: 5, min_samples_leaf: 3, avg_mse: 674.8637847394205
# lr: 1, max_depth: 5, min_samples_leaf: 5, avg_mse: 513.2662709243405
# lr: 1, max_depth: 5, min_samples_leaf: 10, avg_mse: 474.9398121824901
# lr: 1, max_depth: 10, min_samples_leaf: 1, avg_mse: 837.167830019816
# lr: 1, max_depth: 10, min_samples_leaf: 3, avg_mse: 642.2352784086438
# lr: 1, max_depth: 10, min_samples_leaf: 5, avg_mse: 745.6238849701166
# lr: 1, max_depth: 10, min_samples_leaf: 10, avg_mse: 665.8580732718532

# %%
cv_df = pd.DataFrame(best_mses, columns=['Cross-Validation MSE'])
cv_df
# Out:
#    Cross-Validation MSE
# 0            223.179765
# 1             79.630942
# 2            341.164208
# 3            179.809700
# 4            206.722210
# 5             90.952385
# 6            272.385424
# 7            185.198464
# 8            785.044739
# 9             86.222171

# %%
print(f'best lr: {best_lr}, best max_depth: {best_depth}, best min_samples_leaf: {best_msl}, best avg_mse: {np.mean(best_mses)}')
# Out:
# best lr: 0.1, best max_depth: 5, best min_samples_leaf: 10, best avg_mse: 245.0310008487545

# %%
cv_df.to_csv('data/output/cv/gbr_sta_log.csv')

# %%
from sklearn.tree import DecisionTreeRegressor

ccp_alphas = [0.0, 0.01, 0.02, 0.05, 0.1]
min_samples_leafs = [1, 3, 5, 10]
max_depths = [None, 3, 5, 10]

best_mses = []
best_avg_score = 1e9
best_ccp_alpha = None
best_depth = None
best_min_samples_leaf = None
for ccp_alpha in ccp_alphas:
    for depth in max_depths:
        for min_samples_leaf in min_samples_leafs:
            model = DecisionTreeRegressor(ccp_alpha=ccp_alpha, max_depth=depth, min_samples_leaf=min_samples_leaf, random_state=42, min_samples_split=0.01, max_features='sqrt')
            mses = kfold_mse(X_train, y_train, model)
            if np.mean(mses) < best_avg_score:
                best_avg_score = np.mean(mses)
                best_ccp_alpha = ccp_alpha
                best_depth = depth
                best_min_samples_leaf = min_samples_leaf
                best_mses = mses
            print(f'ccp_alpha: {ccp_alpha}, max_depth: {depth}, min_samples_leaf: {min_samples_leaf}, avg_mse: {np.mean(mses)}')
# Out:
# ccp_alpha: 0.0, max_depth: None, min_samples_leaf: 1, avg_mse: 582.6597958501792
# ccp_alpha: 0.0, max_depth: None, min_samples_leaf: 3, avg_mse: 529.448812077285
# ccp_alpha: 0.0, max_depth: None, min_samples_leaf: 5, avg_mse: 532.9028842162293
# ccp_alpha: 0.0, max_depth: None, min_samples_leaf: 10, avg_mse: 536.2032041629008
# ccp_alpha: 0.0, max_depth: 3, min_samples_leaf: 1, avg_mse: 760.5995828163129
# ccp_alpha: 0.0, max_depth: 3, min_samples_leaf: 3, avg_mse: 760.8167050572296
# ccp_alpha: 0.0, max_depth: 3, min_samples_leaf: 5, avg_mse: 760.8219292251181
# ccp_alpha: 0.0, max_depth: 3, min_samples_leaf: 10, avg_mse: 759.0577385978467
# ccp_alpha: 0.0, max_depth: 5, min_samples_leaf: 1, avg_mse: 675.1867704176565
# ccp_alpha: 0.0, max_depth: 5, min_samples_leaf: 3, avg_mse: 689.9640106158282
# ccp_alpha: 0.0, max_depth: 5, min_samples_leaf: 5, avg_mse: 694.1699808907703
# ccp_alpha: 0.0, max_depth: 5, min_samples_leaf: 10, avg_mse: 715.4753494015393
# ccp_alpha: 0.0, max_depth: 10, min_samples_leaf: 1, avg_mse: 562.1795931365011
# ccp_alpha: 0.0, max_depth: 10, min_samples_leaf: 3, avg_mse: 619.3210465223129
# ccp_alpha: 0.0, max_depth: 10, min_samples_leaf: 5, avg_mse: 557.771863267645
# ccp_alpha: 0.0, max_depth: 10, min_samples_leaf: 10, avg_mse: 597.5005752415852
# ccp_alpha: 0.01, max_depth: None, min_samples_leaf: 1, avg_mse: 560.3343663605432
# ccp_alpha: 0.01, max_depth: None, min_samples_leaf: 3, avg_mse: 617.2587584044386
# ccp_alpha: 0.01, max_depth: None, min_samples_leaf: 5, avg_mse: 579.2891237623655
# ccp_alpha: 0.01, max_depth: None, min_samples_leaf: 10, avg_mse: 603.8322967990908
# ccp_alpha: 0.01, max_depth: 3, min_samples_leaf: 1, avg_mse: 756.6373927560993
# ccp_alpha: 0.01, max_depth: 3, min_samples_leaf: 3, avg_mse: 756.6373927560993
# ccp_alpha: 0.01, max_depth: 3, min_samples_leaf: 5, avg_mse: 756.6373927560993
# ccp_alpha: 0.01, max_depth: 3, min_samples_leaf: 10, avg_mse: 756.6373927560993
# ccp_alpha: 0.01, max_depth: 5, min_samples_leaf: 1, avg_mse: 695.7429042666389
# ccp_alpha: 0.01, max_depth: 5, min_samples_leaf: 3, avg_mse: 695.4275392200599
# ccp_alpha: 0.01, max_depth: 5, min_samples_leaf: 5, avg_mse: 701.0440775612608
# ccp_alpha: 0.01, max_depth: 5, min_samples_leaf: 10, avg_mse: 720.0321206831287
# ccp_alpha: 0.01, max_depth: 10, min_samples_leaf: 1, avg_mse: 595.2744701435741
# ccp_alpha: 0.01, max_depth: 10, min_samples_leaf: 3, avg_mse: 643.6554276328723
# ccp_alpha: 0.01, max_depth: 10, min_samples_leaf: 5, avg_mse: 592.8201845270262
# ccp_alpha: 0.01, max_depth: 10, min_samples_leaf: 10, avg_mse: 626.5912986693318
# ccp_alpha: 0.02, max_depth: None, min_samples_leaf: 1, avg_mse: 603.4660439495481
# ccp_alpha: 0.02, max_depth: None, min_samples_leaf: 3, avg_mse: 643.9547171176642
# ccp_alpha: 0.02, max_depth: None, min_samples_leaf: 5, avg_mse: 619.6482067173331
# ccp_alpha: 0.02, max_depth: None, min_samples_leaf: 10, avg_mse: 628.3591620361656
# ccp_alpha: 0.02, max_depth: 3, min_samples_leaf: 1, avg_mse: 756.5071324086623
# ccp_alpha: 0.02, max_depth: 3, min_samples_leaf: 3, avg_mse: 756.5071324086623
# ccp_alpha: 0.02, max_depth: 3, min_samples_leaf: 5, avg_mse: 756.5071324086623
# ccp_alpha: 0.02, max_depth: 3, min_samples_leaf: 10, avg_mse: 756.5071324086623
# ccp_alpha: 0.02, max_depth: 5, min_samples_leaf: 1, avg_mse: 700.1565159291315
# ccp_alpha: 0.02, max_depth: 5, min_samples_leaf: 3, avg_mse: 700.1565159291315
# ccp_alpha: 0.02, max_depth: 5, min_samples_leaf: 5, avg_mse: 703.1604388149858
# ccp_alpha: 0.02, max_depth: 5, min_samples_leaf: 10, avg_mse: 724.4594515129653
# ccp_alpha: 0.02, max_depth: 10, min_samples_leaf: 1, avg_mse: 629.2065509172043
# ccp_alpha: 0.02, max_depth: 10, min_samples_leaf: 3, avg_mse: 653.9542920161787
# ccp_alpha: 0.02, max_depth: 10, min_samples_leaf: 5, avg_mse: 612.023811291632
# ccp_alpha: 0.02, max_depth: 10, min_samples_leaf: 10, avg_mse: 655.6483322227541
# ccp_alpha: 0.05, max_depth: None, min_samples_leaf: 1, avg_mse: 661.7783280687813
# ccp_alpha: 0.05, max_depth: None, min_samples_leaf: 3, avg_mse: 694.7629152127386
# ccp_alpha: 0.05, max_depth: None, min_samples_leaf: 5, avg_mse: 689.5536080504506
# ccp_alpha: 0.05, max_depth: None, min_samples_leaf: 10, avg_mse: 708.0591522952093
# ccp_alpha: 0.05, max_depth: 3, min_samples_leaf: 1, avg_mse: 757.3684199901072
# ccp_alpha: 0.05, max_depth: 3, min_samples_leaf: 3, avg_mse: 757.3684199901072
# ccp_alpha: 0.05, max_depth: 3, min_samples_leaf: 5, avg_mse: 757.3684199901072
# ccp_alpha: 0.05, max_depth: 3, min_samples_leaf: 10, avg_mse: 757.3684199901072
# ccp_alpha: 0.05, max_depth: 5, min_samples_leaf: 1, avg_mse: 700.3806685280331
# ccp_alpha: 0.05, max_depth: 5, min_samples_leaf: 3, avg_mse: 700.3806685280331
# ccp_alpha: 0.05, max_depth: 5, min_samples_leaf: 5, avg_mse: 704.3972259729085
# ccp_alpha: 0.05, max_depth: 5, min_samples_leaf: 10, avg_mse: 728.0842579679528
# ccp_alpha: 0.05, max_depth: 10, min_samples_leaf: 1, avg_mse: 662.0911349982506
# ccp_alpha: 0.05, max_depth: 10, min_samples_leaf: 3, avg_mse: 683.4078022582461
# ccp_alpha: 0.05, max_depth: 10, min_samples_leaf: 5, avg_mse: 648.7133250442566
# ccp_alpha: 0.05, max_depth: 10, min_samples_leaf: 10, avg_mse: 712.4004355513013
# ccp_alpha: 0.1, max_depth: None, min_samples_leaf: 1, avg_mse: 731.1204372755486
# ccp_alpha: 0.1, max_depth: None, min_samples_leaf: 3, avg_mse: 760.1455431915753
# ccp_alpha: 0.1, max_depth: None, min_samples_leaf: 5, avg_mse: 747.1189518924137
# ccp_alpha: 0.1, max_depth: None, min_samples_leaf: 10, avg_mse: 742.6894626429167
# ccp_alpha: 0.1, max_depth: 3, min_samples_leaf: 1, avg_mse: 757.3684199901072
# ccp_alpha: 0.1, max_depth: 3, min_samples_leaf: 3, avg_mse: 757.3684199901072
# ccp_alpha: 0.1, max_depth: 3, min_samples_leaf: 5, avg_mse: 757.3684199901072
# ccp_alpha: 0.1, max_depth: 3, min_samples_leaf: 10, avg_mse: 757.3684199901072
# ccp_alpha: 0.1, max_depth: 5, min_samples_leaf: 1, avg_mse: 715.6756193481814
# ccp_alpha: 0.1, max_depth: 5, min_samples_leaf: 3, avg_mse: 715.6756193481814
# ccp_alpha: 0.1, max_depth: 5, min_samples_leaf: 5, avg_mse: 719.692176793057
# ccp_alpha: 0.1, max_depth: 5, min_samples_leaf: 10, avg_mse: 757.608609398517
# ccp_alpha: 0.1, max_depth: 10, min_samples_leaf: 1, avg_mse: 762.0276423488531
# ccp_alpha: 0.1, max_depth: 10, min_samples_leaf: 3, avg_mse: 751.9186249981896
# ccp_alpha: 0.1, max_depth: 10, min_samples_leaf: 5, avg_mse: 712.35534944993
# ccp_alpha: 0.1, max_depth: 10, min_samples_leaf: 10, avg_mse: 759.3428081446308

# %%
cv_df = pd.DataFrame(best_mses, columns=['Cross-Validation MSE'])
cv_df
# Out:
#    Cross-Validation MSE
# 0            461.495418
# 1            408.030876
# 2            635.322117
# 3            444.929879
# 4            515.511622
# 5            212.891228
# 6            752.387121
# 7            535.975563
# 8           1108.258555
# 9            219.685740

# %%
print(f'best ccp_alpha: {best_ccp_alpha}, best max_depth: {best_depth}, best min_samples_leaf: {best_min_samples_leaf}, best avg_mse: {np.mean(best_mses)}')
# Out:
# best ccp_alpha: 0.0, best max_depth: None, best min_samples_leaf: 3, best avg_mse: 529.448812077285

# %%
cv_df.to_csv('data/output/cv/gt_sta_log.csv')
