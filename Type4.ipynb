# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

X_train = pd.read_csv('data/input/standardized_train_log_sales.csv', index_col=0)
y_train = pd.read_csv('data/input/y_log_train.csv', index_col=0)

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor

def kfold_mse(X, y, model, k=10):
    kf = KFold(n_splits=k)
    mses = []
    for i, (train_idx, val_idx) in enumerate(kf.split(X, y)):
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
        model.fit(X_train, y_train['sales']) # Avoid deprecation warning
        y_pred = model.predict(X_val)
        mses.append(mean_squared_error(np.exp(y_pred), np.exp(y_val['sales'])))
    return mses

ccp_alphas = [0.0, 0.01, 0.05]
min_samples_leafs = [1, 3, 5, 10]
max_depths = [None, 3, 5, 10]

best_mses = []
best_avg_score = 1e9
best_ccp_alpha = None
best_depth = None
best_min_samples_leaf = None
for ccp_alpha in ccp_alphas:
    for depth in max_depths:
        for min_samples_leaf in min_samples_leafs:
            model = RandomForestRegressor(ccp_alpha=ccp_alpha, max_depth=depth, min_samples_leaf=min_samples_leaf, random_state=42, min_samples_split=0.01, max_features='sqrt', n_estimators=1000)
            mses = kfold_mse(X_train, y_train, model)
            if np.mean(mses) < best_avg_score:
                best_avg_score = np.mean(mses)
                best_ccp_alpha = ccp_alpha
                best_depth = depth
                best_min_samples_leaf = min_samples_leaf
                best_mses = mses
            print(f'ccp_alpha: {ccp_alpha}, max_depth: {depth}, min_samples_leaf: {min_samples_leaf}, avg_mse: {np.mean(mses)}')
# Out:
# ccp_alpha: 0.0, max_depth: None, min_samples_leaf: 1, avg_mse: 347.31035645652463
# ccp_alpha: 0.0, max_depth: None, min_samples_leaf: 3, avg_mse: 368.4939603422497
# ccp_alpha: 0.0, max_depth: None, min_samples_leaf: 5, avg_mse: 384.29243118796387
# ccp_alpha: 0.0, max_depth: None, min_samples_leaf: 10, avg_mse: 419.4745978181683
# ccp_alpha: 0.0, max_depth: 3, min_samples_leaf: 1, avg_mse: 658.046826012769
# ccp_alpha: 0.0, max_depth: 3, min_samples_leaf: 3, avg_mse: 658.183045406982
# ccp_alpha: 0.0, max_depth: 3, min_samples_leaf: 5, avg_mse: 658.1633581137626
# ccp_alpha: 0.0, max_depth: 3, min_samples_leaf: 10, avg_mse: 658.979642720413
# ccp_alpha: 0.0, max_depth: 5, min_samples_leaf: 1, avg_mse: 575.4074459878099
# ccp_alpha: 0.0, max_depth: 5, min_samples_leaf: 3, avg_mse: 575.7950135840152
# ccp_alpha: 0.0, max_depth: 5, min_samples_leaf: 5, avg_mse: 576.7481991862041
# ccp_alpha: 0.0, max_depth: 5, min_samples_leaf: 10, avg_mse: 578.6768140501455
# ccp_alpha: 0.0, max_depth: 10, min_samples_leaf: 1, avg_mse: 432.28472204050166
# ccp_alpha: 0.0, max_depth: 10, min_samples_leaf: 3, avg_mse: 434.278269659202
# ccp_alpha: 0.0, max_depth: 10, min_samples_leaf: 5, avg_mse: 441.1324323844503
# ccp_alpha: 0.0, max_depth: 10, min_samples_leaf: 10, avg_mse: 453.7887039214299
# ccp_alpha: 0.01, max_depth: None, min_samples_leaf: 1, avg_mse: 465.33172405004905
# ccp_alpha: 0.01, max_depth: None, min_samples_leaf: 3, avg_mse: 470.53584286251026
# ccp_alpha: 0.01, max_depth: None, min_samples_leaf: 5, avg_mse: 471.64773364219656
# ccp_alpha: 0.01, max_depth: None, min_samples_leaf: 10, avg_mse: 481.56068175915306
# ccp_alpha: 0.01, max_depth: 3, min_samples_leaf: 1, avg_mse: 659.7895775638921
# ccp_alpha: 0.01, max_depth: 3, min_samples_leaf: 3, avg_mse: 659.9668379971284
# ccp_alpha: 0.01, max_depth: 3, min_samples_leaf: 5, avg_mse: 659.8942088466388
# ccp_alpha: 0.01, max_depth: 3, min_samples_leaf: 10, avg_mse: 660.6931803565565
# ccp_alpha: 0.01, max_depth: 5, min_samples_leaf: 1, avg_mse: 582.9100880829783
# ccp_alpha: 0.01, max_depth: 5, min_samples_leaf: 3, avg_mse: 583.5058706794428
# ccp_alpha: 0.01, max_depth: 5, min_samples_leaf: 5, avg_mse: 584.546487344479
# ccp_alpha: 0.01, max_depth: 5, min_samples_leaf: 10, avg_mse: 585.938756155844
# ccp_alpha: 0.01, max_depth: 10, min_samples_leaf: 1, avg_mse: 484.22009159326865
# ccp_alpha: 0.01, max_depth: 10, min_samples_leaf: 3, avg_mse: 484.704087728619
# ccp_alpha: 0.01, max_depth: 10, min_samples_leaf: 5, avg_mse: 489.3686109308861
# ccp_alpha: 0.01, max_depth: 10, min_samples_leaf: 10, avg_mse: 494.84213367912173
# ccp_alpha: 0.05, max_depth: None, min_samples_leaf: 1, avg_mse: 588.759986234151
# ccp_alpha: 0.05, max_depth: None, min_samples_leaf: 3, avg_mse: 591.1626251756778
# ccp_alpha: 0.05, max_depth: None, min_samples_leaf: 5, avg_mse: 587.5613738744476
# ccp_alpha: 0.05, max_depth: None, min_samples_leaf: 10, avg_mse: 589.6102131985612
# ccp_alpha: 0.05, max_depth: 3, min_samples_leaf: 1, avg_mse: 670.6854176360863
# ccp_alpha: 0.05, max_depth: 3, min_samples_leaf: 3, avg_mse: 670.8076547164359
# ccp_alpha: 0.05, max_depth: 3, min_samples_leaf: 5, avg_mse: 670.6764150775177
# ccp_alpha: 0.05, max_depth: 3, min_samples_leaf: 10, avg_mse: 671.5218602059182
# ccp_alpha: 0.05, max_depth: 5, min_samples_leaf: 1, avg_mse: 618.6006968674238
# ccp_alpha: 0.05, max_depth: 5, min_samples_leaf: 3, avg_mse: 619.2415462239261
# ccp_alpha: 0.05, max_depth: 5, min_samples_leaf: 5, avg_mse: 619.7530445433255
# ccp_alpha: 0.05, max_depth: 5, min_samples_leaf: 10, avg_mse: 621.2103094335002
# ccp_alpha: 0.05, max_depth: 10, min_samples_leaf: 1, avg_mse: 589.9262245540189
# ccp_alpha: 0.05, max_depth: 10, min_samples_leaf: 3, avg_mse: 589.596079096284
# ccp_alpha: 0.05, max_depth: 10, min_samples_leaf: 5, avg_mse: 590.7535494008425
# ccp_alpha: 0.05, max_depth: 10, min_samples_leaf: 10, avg_mse: 591.1127029838002

# %%
cv_df = pd.DataFrame(best_mses, columns=['Cross-Validation MSE'])
cv_df
# Out:
#    Cross-Validation MSE
# 0            355.575399
# 1            140.712250
# 2            390.811499
# 3            243.544602
# 4            338.483561
# 5            104.000829
# 6            568.613525
# 7            314.707569
# 8            953.899597
# 9             62.754733

# %%
print(f'best ccp_alpha: {best_ccp_alpha}, best max_depth: {best_depth}, best min_samples_leaf: {best_min_samples_leaf}, best avg_mse: {np.mean(best_mses)}')
# Out:
# best ccp_alpha: 0.0, best max_depth: None, best min_samples_leaf: 1, best avg_mse: 347.31035645652463

# %%
from sklearn.ensemble import GradientBoostingRegressor

learning_rates = [0.01, 0.1, 0.5, 1]
max_depths = [None, 3, 5, 10]
min_samples_leafs = [1, 3, 5, 10]

best_mses = []
best_avg_score = 1e9
best_lr = None
best_depth = None
best_msl = None
for lr in learning_rates:
    for depth in max_depths:
        for min_samples_leaf in min_samples_leafs:
            model = GradientBoostingRegressor(min_samples_leaf=min_samples_leaf, min_samples_split=0.01, n_estimators=1000, max_features='sqrt', random_state=42, learning_rate=lr, max_depth=depth)
            mses = kfold_mse(X_train, y_train, model)
            if np.mean(mses) < best_avg_score:
                best_avg_score = np.mean(mses)
                best_lr = lr
                best_depth = depth
                best_msl = min_samples_leaf
                best_mses = mses
            print(f'lr: {lr}, max_depth: {depth}, min_samples_leaf: {min_samples_leaf}, avg_mse: {np.mean(mses)}')
# Out:
# lr: 0.01, max_depth: None, min_samples_leaf: 1, avg_mse: 197.96634481108896
# lr: 0.01, max_depth: None, min_samples_leaf: 3, avg_mse: 158.33171445540404
# lr: 0.01, max_depth: None, min_samples_leaf: 5, avg_mse: 151.55345697124227
# lr: 0.01, max_depth: None, min_samples_leaf: 10, avg_mse: 141.9555845009017
# lr: 0.01, max_depth: 3, min_samples_leaf: 1, avg_mse: 254.49131159522267
# lr: 0.01, max_depth: 3, min_samples_leaf: 3, avg_mse: 248.23425961801323
# lr: 0.01, max_depth: 3, min_samples_leaf: 5, avg_mse: 246.81220939062638
# lr: 0.01, max_depth: 3, min_samples_leaf: 10, avg_mse: 246.7766027692732
# lr: 0.01, max_depth: 5, min_samples_leaf: 1, avg_mse: 191.69421068833256
# lr: 0.01, max_depth: 5, min_samples_leaf: 3, avg_mse: 185.6358720539944
# lr: 0.01, max_depth: 5, min_samples_leaf: 5, avg_mse: 186.76093194962598
# lr: 0.01, max_depth: 5, min_samples_leaf: 10, avg_mse: 183.51405435738042
# lr: 0.01, max_depth: 10, min_samples_leaf: 1, avg_mse: 180.73526365136405
# lr: 0.01, max_depth: 10, min_samples_leaf: 3, avg_mse: 161.99003109940918
# lr: 0.01, max_depth: 10, min_samples_leaf: 5, avg_mse: 158.8717004026376
# lr: 0.01, max_depth: 10, min_samples_leaf: 10, avg_mse: 143.19207510537672
# lr: 0.1, max_depth: None, min_samples_leaf: 1, avg_mse: 200.78568574815736
# lr: 0.1, max_depth: None, min_samples_leaf: 3, avg_mse: 162.6244066402916
# lr: 0.1, max_depth: None, min_samples_leaf: 5, avg_mse: 147.34964710692185
# lr: 0.1, max_depth: None, min_samples_leaf: 10, avg_mse: 142.7596206907321
# lr: 0.1, max_depth: 3, min_samples_leaf: 1, avg_mse: 119.45520468125275
# lr: 0.1, max_depth: 3, min_samples_leaf: 3, avg_mse: 110.93106068814325
# lr: 0.1, max_depth: 3, min_samples_leaf: 5, avg_mse: 105.47935343581443
# lr: 0.1, max_depth: 3, min_samples_leaf: 10, avg_mse: 100.06413322871329
# lr: 0.1, max_depth: 5, min_samples_leaf: 1, avg_mse: 135.78200243734716
# lr: 0.1, max_depth: 5, min_samples_leaf: 3, avg_mse: 107.70186237796675
# lr: 0.1, max_depth: 5, min_samples_leaf: 5, avg_mse: 101.57318799970997
# lr: 0.1, max_depth: 5, min_samples_leaf: 10, avg_mse: 106.39742642571434
# lr: 0.1, max_depth: 10, min_samples_leaf: 1, avg_mse: 172.1122535246575
# lr: 0.1, max_depth: 10, min_samples_leaf: 3, avg_mse: 142.92771419060122
# lr: 0.1, max_depth: 10, min_samples_leaf: 5, avg_mse: 133.19312141966222
# lr: 0.1, max_depth: 10, min_samples_leaf: 10, avg_mse: 114.05435736803231
# lr: 0.5, max_depth: None, min_samples_leaf: 1, avg_mse: 230.7693223987625
# lr: 0.5, max_depth: None, min_samples_leaf: 3, avg_mse: 221.62075444756903
# lr: 0.5, max_depth: None, min_samples_leaf: 5, avg_mse: 207.38611944077735
# lr: 0.5, max_depth: None, min_samples_leaf: 10, avg_mse: 182.93942660870056
# lr: 0.5, max_depth: 3, min_samples_leaf: 1, avg_mse: 137.6668194238716
# lr: 0.5, max_depth: 3, min_samples_leaf: 3, avg_mse: 129.40033743285974
# lr: 0.5, max_depth: 3, min_samples_leaf: 5, avg_mse: 141.9003017745089
# lr: 0.5, max_depth: 3, min_samples_leaf: 10, avg_mse: 138.80981747875722
# lr: 0.5, max_depth: 5, min_samples_leaf: 1, avg_mse: 138.43859235135767
# lr: 0.5, max_depth: 5, min_samples_leaf: 3, avg_mse: 147.52153637369855
# lr: 0.5, max_depth: 5, min_samples_leaf: 5, avg_mse: 150.89637869261838
# lr: 0.5, max_depth: 5, min_samples_leaf: 10, avg_mse: 142.26729281518033
# lr: 0.5, max_depth: 10, min_samples_leaf: 1, avg_mse: 202.58140463126372
# lr: 0.5, max_depth: 10, min_samples_leaf: 3, avg_mse: 180.80817294294724
# lr: 0.5, max_depth: 10, min_samples_leaf: 5, avg_mse: 144.1712451516125
# lr: 0.5, max_depth: 10, min_samples_leaf: 10, avg_mse: 175.29229645747535
# lr: 1, max_depth: None, min_samples_leaf: 1, avg_mse: 482.32690843142564
# lr: 1, max_depth: None, min_samples_leaf: 3, avg_mse: 567.2232810140324
# lr: 1, max_depth: None, min_samples_leaf: 5, avg_mse: 500.04812952165076
# lr: 1, max_depth: None, min_samples_leaf: 10, avg_mse: 666.6647204386445
# lr: 1, max_depth: 3, min_samples_leaf: 1, avg_mse: 224.85953942643943
# lr: 1, max_depth: 3, min_samples_leaf: 3, avg_mse: 245.5375550551675
# lr: 1, max_depth: 3, min_samples_leaf: 5, avg_mse: 226.28506776213288
# lr: 1, max_depth: 3, min_samples_leaf: 10, avg_mse: 190.2348390840408
# lr: 1, max_depth: 5, min_samples_leaf: 1, avg_mse: 316.7368522860934
# lr: 1, max_depth: 5, min_samples_leaf: 3, avg_mse: 353.33481336334887
# lr: 1, max_depth: 5, min_samples_leaf: 5, avg_mse: 320.1630250125777
# lr: 1, max_depth: 5, min_samples_leaf: 10, avg_mse: 346.3574672761691
# lr: 1, max_depth: 10, min_samples_leaf: 1, avg_mse: 487.4875645345022
# lr: 1, max_depth: 10, min_samples_leaf: 3, avg_mse: 618.4724704217103
# lr: 1, max_depth: 10, min_samples_leaf: 5, avg_mse: 475.5784369419359
# lr: 1, max_depth: 10, min_samples_leaf: 10, avg_mse: 488.19477702889145

# %%
cv_df = pd.DataFrame(best_mses, columns=['Cross-Validation MSE'])
cv_df
# Out:
#    Cross-Validation MSE
# 0             18.928878
# 1             22.303529
# 2            220.840145
# 3             52.822040
# 4             45.455427
# 5             23.653805
# 6             95.550959
# 7             32.560332
# 8            468.983601
# 9             19.542616

# %%
print(f'best lr: {best_lr}, best max_depth: {best_depth}, best min_samples_leaf: {best_msl}, best avg_mse: {np.mean(best_mses)}')
# Out:
# best lr: 0.1, best max_depth: 3, best min_samples_leaf: 10, best avg_mse: 100.06413322871329

# %%
from sklearn.tree import DecisionTreeRegressor

ccp_alphas = [0.0, 0.01, 0.02, 0.05, 0.1]
min_samples_leafs = [1, 3, 5, 10]
max_depths = [None, 3, 5, 10]

best_mses = []
best_avg_score = 1e9
best_ccp_alpha = None
best_depth = None
best_min_samples_leaf = None
for ccp_alpha in ccp_alphas:
    for depth in max_depths:
        for min_samples_leaf in min_samples_leafs:
            model = DecisionTreeRegressor(ccp_alpha=ccp_alpha, max_depth=depth, min_samples_leaf=min_samples_leaf, random_state=42, min_samples_split=0.01, max_features='sqrt')
            mses = kfold_mse(X_train, y_train, model)
            if np.mean(mses) < best_avg_score:
                best_avg_score = np.mean(mses)
                best_ccp_alpha = ccp_alpha
                best_depth = depth
                best_min_samples_leaf = min_samples_leaf
                best_mses = mses
            print(f'ccp_alpha: {ccp_alpha}, max_depth: {depth}, min_samples_leaf: {min_samples_leaf}, avg_mse: {np.mean(mses)}')
# Out:
# ccp_alpha: 0.0, max_depth: None, min_samples_leaf: 1, avg_mse: 444.91878364511183
# ccp_alpha: 0.0, max_depth: None, min_samples_leaf: 3, avg_mse: 428.5485559805209
# ccp_alpha: 0.0, max_depth: None, min_samples_leaf: 5, avg_mse: 366.08494364672686
# ccp_alpha: 0.0, max_depth: None, min_samples_leaf: 10, avg_mse: 435.2059374410425
# ccp_alpha: 0.0, max_depth: 3, min_samples_leaf: 1, avg_mse: 690.1374170432966
# ccp_alpha: 0.0, max_depth: 3, min_samples_leaf: 3, avg_mse: 690.1278760927732
# ccp_alpha: 0.0, max_depth: 3, min_samples_leaf: 5, avg_mse: 671.796141106811
# ccp_alpha: 0.0, max_depth: 3, min_samples_leaf: 10, avg_mse: 669.4903366563216
# ccp_alpha: 0.0, max_depth: 5, min_samples_leaf: 1, avg_mse: 619.326419895111
# ccp_alpha: 0.0, max_depth: 5, min_samples_leaf: 3, avg_mse: 640.4536096720785
# ccp_alpha: 0.0, max_depth: 5, min_samples_leaf: 5, avg_mse: 554.8433781152224
# ccp_alpha: 0.0, max_depth: 5, min_samples_leaf: 10, avg_mse: 638.0310534964899
# ccp_alpha: 0.0, max_depth: 10, min_samples_leaf: 1, avg_mse: 498.7618030880029
# ccp_alpha: 0.0, max_depth: 10, min_samples_leaf: 3, avg_mse: 450.523618826577
# ccp_alpha: 0.0, max_depth: 10, min_samples_leaf: 5, avg_mse: 405.44681517587225
# ccp_alpha: 0.0, max_depth: 10, min_samples_leaf: 10, avg_mse: 471.55316205391034
# ccp_alpha: 0.01, max_depth: None, min_samples_leaf: 1, avg_mse: 504.13459314589636
# ccp_alpha: 0.01, max_depth: None, min_samples_leaf: 3, avg_mse: 509.33252899262925
# ccp_alpha: 0.01, max_depth: None, min_samples_leaf: 5, avg_mse: 462.4004126392594
# ccp_alpha: 0.01, max_depth: None, min_samples_leaf: 10, avg_mse: 509.9729439856927
# ccp_alpha: 0.01, max_depth: 3, min_samples_leaf: 1, avg_mse: 690.2140135068024
# ccp_alpha: 0.01, max_depth: 3, min_samples_leaf: 3, avg_mse: 690.2140135068024
# ccp_alpha: 0.01, max_depth: 3, min_samples_leaf: 5, avg_mse: 672.3096931492362
# ccp_alpha: 0.01, max_depth: 3, min_samples_leaf: 10, avg_mse: 672.3096931492362
# ccp_alpha: 0.01, max_depth: 5, min_samples_leaf: 1, avg_mse: 630.7934110012069
# ccp_alpha: 0.01, max_depth: 5, min_samples_leaf: 3, avg_mse: 652.026510525306
# ccp_alpha: 0.01, max_depth: 5, min_samples_leaf: 5, avg_mse: 558.2686526766777
# ccp_alpha: 0.01, max_depth: 5, min_samples_leaf: 10, avg_mse: 646.8225465970977
# ccp_alpha: 0.01, max_depth: 10, min_samples_leaf: 1, avg_mse: 492.34042569589275
# ccp_alpha: 0.01, max_depth: 10, min_samples_leaf: 3, avg_mse: 510.00445328879766
# ccp_alpha: 0.01, max_depth: 10, min_samples_leaf: 5, avg_mse: 472.6730002483785
# ccp_alpha: 0.01, max_depth: 10, min_samples_leaf: 10, avg_mse: 505.3557630946925
# ccp_alpha: 0.02, max_depth: None, min_samples_leaf: 1, avg_mse: 544.4136807810222
# ccp_alpha: 0.02, max_depth: None, min_samples_leaf: 3, avg_mse: 540.0592048355718
# ccp_alpha: 0.02, max_depth: None, min_samples_leaf: 5, avg_mse: 508.3053937276958
# ccp_alpha: 0.02, max_depth: None, min_samples_leaf: 10, avg_mse: 528.2362139139278
# ccp_alpha: 0.02, max_depth: 3, min_samples_leaf: 1, avg_mse: 690.2140135068024
# ccp_alpha: 0.02, max_depth: 3, min_samples_leaf: 3, avg_mse: 690.2140135068024
# ccp_alpha: 0.02, max_depth: 3, min_samples_leaf: 5, avg_mse: 672.3096931492362
# ccp_alpha: 0.02, max_depth: 3, min_samples_leaf: 10, avg_mse: 672.3096931492362
# ccp_alpha: 0.02, max_depth: 5, min_samples_leaf: 1, avg_mse: 644.0364438906711
# ccp_alpha: 0.02, max_depth: 5, min_samples_leaf: 3, avg_mse: 666.0685166598837
# ccp_alpha: 0.02, max_depth: 5, min_samples_leaf: 5, avg_mse: 569.9321035134627
# ccp_alpha: 0.02, max_depth: 5, min_samples_leaf: 10, avg_mse: 647.6992261192333
# ccp_alpha: 0.02, max_depth: 10, min_samples_leaf: 1, avg_mse: 530.8930232446921
# ccp_alpha: 0.02, max_depth: 10, min_samples_leaf: 3, avg_mse: 524.9157398739354
# ccp_alpha: 0.02, max_depth: 10, min_samples_leaf: 5, avg_mse: 511.61108838134953
# ccp_alpha: 0.02, max_depth: 10, min_samples_leaf: 10, avg_mse: 534.0234317083867
# ccp_alpha: 0.05, max_depth: None, min_samples_leaf: 1, avg_mse: 613.7906945011221
# ccp_alpha: 0.05, max_depth: None, min_samples_leaf: 3, avg_mse: 645.7863021056205
# ccp_alpha: 0.05, max_depth: None, min_samples_leaf: 5, avg_mse: 531.6430390623588
# ccp_alpha: 0.05, max_depth: None, min_samples_leaf: 10, avg_mse: 629.128913665086
# ccp_alpha: 0.05, max_depth: 3, min_samples_leaf: 1, avg_mse: 690.2140135068024
# ccp_alpha: 0.05, max_depth: 3, min_samples_leaf: 3, avg_mse: 690.2140135068024
# ccp_alpha: 0.05, max_depth: 3, min_samples_leaf: 5, avg_mse: 672.3096931492362
# ccp_alpha: 0.05, max_depth: 3, min_samples_leaf: 10, avg_mse: 672.3096931492362
# ccp_alpha: 0.05, max_depth: 5, min_samples_leaf: 1, avg_mse: 661.0083408982503
# ccp_alpha: 0.05, max_depth: 5, min_samples_leaf: 3, avg_mse: 683.9155827158136
# ccp_alpha: 0.05, max_depth: 5, min_samples_leaf: 5, avg_mse: 597.5331960704848
# ccp_alpha: 0.05, max_depth: 5, min_samples_leaf: 10, avg_mse: 659.5232895960503
# ccp_alpha: 0.05, max_depth: 10, min_samples_leaf: 1, avg_mse: 548.273658018089
# ccp_alpha: 0.05, max_depth: 10, min_samples_leaf: 3, avg_mse: 591.4681453254298
# ccp_alpha: 0.05, max_depth: 10, min_samples_leaf: 5, avg_mse: 552.9425797325686
# ccp_alpha: 0.05, max_depth: 10, min_samples_leaf: 10, avg_mse: 585.4484074231766
# ccp_alpha: 0.1, max_depth: None, min_samples_leaf: 1, avg_mse: 714.4539856173099
# ccp_alpha: 0.1, max_depth: None, min_samples_leaf: 3, avg_mse: 693.9525658626508
# ccp_alpha: 0.1, max_depth: None, min_samples_leaf: 5, avg_mse: 644.7271903645749
# ccp_alpha: 0.1, max_depth: None, min_samples_leaf: 10, avg_mse: 685.2878444121196
# ccp_alpha: 0.1, max_depth: 3, min_samples_leaf: 1, avg_mse: 697.7160950542752
# ccp_alpha: 0.1, max_depth: 3, min_samples_leaf: 3, avg_mse: 697.7160950542752
# ccp_alpha: 0.1, max_depth: 3, min_samples_leaf: 5, avg_mse: 672.3096931492362
# ccp_alpha: 0.1, max_depth: 3, min_samples_leaf: 10, avg_mse: 672.3096931492362
# ccp_alpha: 0.1, max_depth: 5, min_samples_leaf: 1, avg_mse: 695.6769424613819
# ccp_alpha: 0.1, max_depth: 5, min_samples_leaf: 3, avg_mse: 712.7344392512539
# ccp_alpha: 0.1, max_depth: 5, min_samples_leaf: 5, avg_mse: 653.926383784227
# ccp_alpha: 0.1, max_depth: 5, min_samples_leaf: 10, avg_mse: 711.24078053063
# ccp_alpha: 0.1, max_depth: 10, min_samples_leaf: 1, avg_mse: 564.5561473170098
# ccp_alpha: 0.1, max_depth: 10, min_samples_leaf: 3, avg_mse: 615.7697793516838
# ccp_alpha: 0.1, max_depth: 10, min_samples_leaf: 5, avg_mse: 627.4600456561599
# ccp_alpha: 0.1, max_depth: 10, min_samples_leaf: 10, avg_mse: 635.5611609633291

# %%
cv_df = pd.DataFrame(best_mses, columns=['Cross-Validation MSE'])
cv_df
# Out:
#    Cross-Validation MSE
# 0            450.858102
# 1            138.288108
# 2            587.941556
# 3            135.070283
# 4            460.580141
# 5            180.019215
# 6            552.358138
# 7            274.216715
# 8            830.404742
# 9             51.112435

# %%
print(f'best ccp_alpha: {best_ccp_alpha}, best max_depth: {best_depth}, best min_samples_leaf: {best_min_samples_leaf}, best avg_mse: {np.mean(best_mses)}')
# Out:
# best ccp_alpha: 0.0, best max_depth: None, best min_samples_leaf: 5, best avg_mse: 366.08494364672686
