# %% [markdown]
# ### **Import Libraries**

# %%
import pandas as pd
import numpy as np
import datetime
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator, MonthLocator, DateFormatter

import pycaret.time_series
from pycaret.regression import *
import xgboost

from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, MinMaxScaler
from sklearn.model_selection import TimeSeriesSplit
import sklearn

import json
import glob
import os

# %% [markdown]
# ### **Load Data**

# %%
data = pd.read_csv('data/input/non_standardized_train.csv', index_col=0)
data_l = pd.read_csv('data/input/non_standardized_train_log_sales.csv', index_col=0)

data_s = pd.read_csv('data/input/standardized_train.csv', index_col=0)
data_sl = pd.read_csv('data/input/standardized_train_log_sales.csv', index_col=0)

# %% [markdown]
# ### **Type 1: Not Standardized, Sales Unchanged**

# %%
from sklearn.model_selection import train_test_split, KFold
# train_data, test_data = train_test_split(data, test_size=0.2, random_state=42, shuffle=True)

kf = KFold(n_splits=5)

setup_1 = setup(data = data, test_data = data, target = 'sales', 
                fold_strategy = kf, transform_target = False, preprocess=False, data_split_shuffle = True,
                session_id = 0)

best_model_1 = compare_models(exclude = ["lar"], n_select = 3)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2f610">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f610_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2f610_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f610_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2f610_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2f610_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2f610_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2f610_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2f610_row1_col1" class="data row1 col1" >sales</td>
#     </tr>
#     <tr>
#       <th id="T_2f610_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2f610_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_2f610_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_2f610_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2f610_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_2f610_row3_col1" class="data row3 col1" >(4422, 166)</td>
#     </tr>
#     <tr>
#       <th id="T_2f610_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2f610_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_2f610_row4_col1" class="data row4 col1" >(4422, 166)</td>
#     </tr>
#     <tr>
#       <th id="T_2f610_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2f610_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_2f610_row5_col1" class="data row5 col1" >(2211, 166)</td>
#     </tr>
#     <tr>
#       <th id="T_2f610_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2f610_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_2f610_row6_col1" class="data row6 col1" >(2211, 166)</td>
#     </tr>
#     <tr>
#       <th id="T_2f610_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2f610_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_2f610_row7_col1" class="data row7 col1" >165</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c10e8 th {
#   text-align: left;
# }
# #T_c10e8_row0_col0, #T_c10e8_row1_col0, #T_c10e8_row1_col1, #T_c10e8_row1_col2, #T_c10e8_row1_col3, #T_c10e8_row1_col4, #T_c10e8_row1_col5, #T_c10e8_row1_col6, #T_c10e8_row2_col0, #T_c10e8_row2_col1, #T_c10e8_row2_col2, #T_c10e8_row2_col3, #T_c10e8_row2_col4, #T_c10e8_row2_col5, #T_c10e8_row2_col6, #T_c10e8_row3_col0, #T_c10e8_row3_col1, #T_c10e8_row3_col2, #T_c10e8_row3_col3, #T_c10e8_row3_col4, #T_c10e8_row3_col5, #T_c10e8_row3_col6, #T_c10e8_row4_col0, #T_c10e8_row4_col1, #T_c10e8_row4_col2, #T_c10e8_row4_col3, #T_c10e8_row4_col4, #T_c10e8_row4_col5, #T_c10e8_row4_col6, #T_c10e8_row5_col0, #T_c10e8_row5_col1, #T_c10e8_row5_col2, #T_c10e8_row5_col3, #T_c10e8_row5_col4, #T_c10e8_row5_col5, #T_c10e8_row5_col6, #T_c10e8_row6_col0, #T_c10e8_row6_col1, #T_c10e8_row6_col2, #T_c10e8_row6_col3, #T_c10e8_row6_col4, #T_c10e8_row6_col5, #T_c10e8_row6_col6, #T_c10e8_row7_col0, #T_c10e8_row7_col1, #T_c10e8_row7_col2, #T_c10e8_row7_col3, #T_c10e8_row7_col4, #T_c10e8_row7_col5, #T_c10e8_row7_col6, #T_c10e8_row8_col0, #T_c10e8_row8_col1, #T_c10e8_row8_col2, #T_c10e8_row8_col3, #T_c10e8_row8_col4, #T_c10e8_row8_col5, #T_c10e8_row8_col6, #T_c10e8_row9_col0, #T_c10e8_row9_col1, #T_c10e8_row9_col2, #T_c10e8_row9_col3, #T_c10e8_row9_col4, #T_c10e8_row9_col5, #T_c10e8_row9_col6, #T_c10e8_row10_col0, #T_c10e8_row10_col1, #T_c10e8_row10_col2, #T_c10e8_row10_col3, #T_c10e8_row10_col4, #T_c10e8_row10_col5, #T_c10e8_row10_col6, #T_c10e8_row11_col0, #T_c10e8_row11_col1, #T_c10e8_row11_col2, #T_c10e8_row11_col3, #T_c10e8_row11_col4, #T_c10e8_row11_col5, #T_c10e8_row11_col6, #T_c10e8_row12_col0, #T_c10e8_row12_col1, #T_c10e8_row12_col2, #T_c10e8_row12_col3, #T_c10e8_row12_col4, #T_c10e8_row12_col5, #T_c10e8_row12_col6, #T_c10e8_row13_col0, #T_c10e8_row13_col1, #T_c10e8_row13_col2, #T_c10e8_row13_col3, #T_c10e8_row13_col4, #T_c10e8_row13_col5, #T_c10e8_row13_col6, #T_c10e8_row14_col0, #T_c10e8_row14_col1, #T_c10e8_row14_col2, #T_c10e8_row14_col3, #T_c10e8_row14_col4, #T_c10e8_row14_col5, #T_c10e8_row14_col6, #T_c10e8_row15_col0, #T_c10e8_row15_col1, #T_c10e8_row15_col2, #T_c10e8_row15_col3, #T_c10e8_row15_col4, #T_c10e8_row15_col5, #T_c10e8_row15_col6, #T_c10e8_row16_col0, #T_c10e8_row16_col1, #T_c10e8_row16_col2, #T_c10e8_row16_col3, #T_c10e8_row16_col4, #T_c10e8_row16_col5, #T_c10e8_row16_col6, #T_c10e8_row17_col0, #T_c10e8_row17_col1, #T_c10e8_row17_col2, #T_c10e8_row17_col3, #T_c10e8_row17_col4, #T_c10e8_row17_col5, #T_c10e8_row17_col6, #T_c10e8_row18_col0, #T_c10e8_row18_col1, #T_c10e8_row18_col2, #T_c10e8_row18_col3, #T_c10e8_row18_col4, #T_c10e8_row18_col5, #T_c10e8_row18_col6 {
#   text-align: left;
# }
# #T_c10e8_row0_col1, #T_c10e8_row0_col2, #T_c10e8_row0_col3, #T_c10e8_row0_col4, #T_c10e8_row0_col5, #T_c10e8_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_c10e8_row0_col7, #T_c10e8_row1_col7, #T_c10e8_row2_col7, #T_c10e8_row3_col7, #T_c10e8_row4_col7, #T_c10e8_row5_col7, #T_c10e8_row6_col7, #T_c10e8_row7_col7, #T_c10e8_row8_col7, #T_c10e8_row9_col7, #T_c10e8_row10_col7, #T_c10e8_row12_col7, #T_c10e8_row13_col7, #T_c10e8_row14_col7, #T_c10e8_row15_col7, #T_c10e8_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_c10e8_row11_col7, #T_c10e8_row16_col7, #T_c10e8_row18_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_c10e8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c10e8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c10e8_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c10e8_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c10e8_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c10e8_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c10e8_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c10e8_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_c10e8_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c10e8_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_c10e8_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_c10e8_row0_col1" class="data row0 col1" >6.2047</td>
#       <td id="T_c10e8_row0_col2" class="data row0 col2" >246.1775</td>
#       <td id="T_c10e8_row0_col3" class="data row0 col3" >15.3094</td>
#       <td id="T_c10e8_row0_col4" class="data row0 col4" >0.6832</td>
#       <td id="T_c10e8_row0_col5" class="data row0 col5" >0.4556</td>
#       <td id="T_c10e8_row0_col6" class="data row0 col6" >0.5640</td>
#       <td id="T_c10e8_row0_col7" class="data row0 col7" >0.5700</td>
#     </tr>
#     <tr>
#       <th id="T_c10e8_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_c10e8_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_c10e8_row1_col1" class="data row1 col1" >6.4866</td>
#       <td id="T_c10e8_row1_col2" class="data row1 col2" >269.5358</td>
#       <td id="T_c10e8_row1_col3" class="data row1 col3" >16.0685</td>
#       <td id="T_c10e8_row1_col4" class="data row1 col4" >0.6534</td>
#       <td id="T_c10e8_row1_col5" class="data row1 col5" >0.4601</td>
#       <td id="T_c10e8_row1_col6" class="data row1 col6" >0.6195</td>
#       <td id="T_c10e8_row1_col7" class="data row1 col7" >0.2680</td>
#     </tr>
#     <tr>
#       <th id="T_c10e8_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_c10e8_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_c10e8_row2_col1" class="data row2 col1" >6.7824</td>
#       <td id="T_c10e8_row2_col2" class="data row2 col2" >276.1702</td>
#       <td id="T_c10e8_row2_col3" class="data row2 col3" >16.1372</td>
#       <td id="T_c10e8_row2_col4" class="data row2 col4" >0.6441</td>
#       <td id="T_c10e8_row2_col5" class="data row2 col5" >0.4852</td>
#       <td id="T_c10e8_row2_col6" class="data row2 col6" >0.6889</td>
#       <td id="T_c10e8_row2_col7" class="data row2 col7" >0.2560</td>
#     </tr>
#     <tr>
#       <th id="T_c10e8_level0_row3" class="row_heading level0 row3" >xgboost</th>
#       <td id="T_c10e8_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_c10e8_row3_col1" class="data row3 col1" >6.6715</td>
#       <td id="T_c10e8_row3_col2" class="data row3 col2" >277.7125</td>
#       <td id="T_c10e8_row3_col3" class="data row3 col3" >16.3602</td>
#       <td id="T_c10e8_row3_col4" class="data row3 col4" >0.6382</td>
#       <td id="T_c10e8_row3_col5" class="data row3 col5" >0.4814</td>
#       <td id="T_c10e8_row3_col6" class="data row3 col6" >0.6317</td>
#       <td id="T_c10e8_row3_col7" class="data row3 col7" >0.2360</td>
#     </tr>
#     <tr>
#       <th id="T_c10e8_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_c10e8_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_c10e8_row4_col1" class="data row4 col1" >6.9205</td>
#       <td id="T_c10e8_row4_col2" class="data row4 col2" >283.2230</td>
#       <td id="T_c10e8_row4_col3" class="data row4 col3" >16.3955</td>
#       <td id="T_c10e8_row4_col4" class="data row4 col4" >0.6354</td>
#       <td id="T_c10e8_row4_col5" class="data row4 col5" >0.5194</td>
#       <td id="T_c10e8_row4_col6" class="data row4 col6" >0.7146</td>
#       <td id="T_c10e8_row4_col7" class="data row4 col7" >0.1400</td>
#     </tr>
#     <tr>
#       <th id="T_c10e8_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_c10e8_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_c10e8_row5_col1" class="data row5 col1" >6.8525</td>
#       <td id="T_c10e8_row5_col2" class="data row5 col2" >290.3424</td>
#       <td id="T_c10e8_row5_col3" class="data row5 col3" >16.6841</td>
#       <td id="T_c10e8_row5_col4" class="data row5 col4" >0.6223</td>
#       <td id="T_c10e8_row5_col5" class="data row5 col5" >0

# %%
for i in best_model_1:
    print("Model Type: ", i)
    print("Hyperparamters: ", i.get_params())
    print("+++++++++++++++++++++++++++++++++")
# Out:
# Model Type:  <catboost.core.CatBoostRegressor object at 0x1538d0550>
# Hyperparamters:  {'loss_function': 'RMSE', 'border_count': 254, 'verbose': False, 'task_type': 'CPU', 'random_state': 0}
# +++++++++++++++++++++++++++++++++
# Model Type:  ExtraTreesRegressor(n_jobs=-1, random_state=0)
# Hyperparamters:  {'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_jobs': -1, 'oob_score': False, 'random_state': 0, 'verbose': 0, 'warm_start': False}
# +++++++++++++++++++++++++++++++++
# Model Type:  RandomForestRegressor(n_jobs=-1, random_state=0)
# Hyperparamters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_jobs': -1, 'oob_score': False, 'random_state': 0, 'verbose': 0, 'warm_start': False}
# +++++++++++++++++++++++++++++++++

# %% [markdown]
# ### **Type 2: Not Standardized, Log Sales**

# %%
#train_data_l, test_data_l = train_test_split(data_l, test_size=0.2, random_state=42, shuffle=True)

kf = KFold(n_splits=5)

setup_2 = setup(data = data_l, test_data = data_l, target = 'sales', 
                fold_strategy = kf, transform_target = False, preprocess=False, data_split_shuffle = True,
                session_id = 0)

best_model_2 = compare_models(exclude = ["lar"], n_select = 3)
# Out:
# <style type="text/css">
# </style>
# <table id="T_59d93">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_59d93_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_59d93_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_59d93_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_59d93_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_59d93_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_59d93_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_59d93_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_59d93_row1_col1" class="data row1 col1" >sales</td>
#     </tr>
#     <tr>
#       <th id="T_59d93_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_59d93_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_59d93_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_59d93_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_59d93_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_59d93_row3_col1" class="data row3 col1" >(4422, 166)</td>
#     </tr>
#     <tr>
#       <th id="T_59d93_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_59d93_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_59d93_row4_col1" class="data row4 col1" >(4422, 166)</td>
#     </tr>
#     <tr>
#       <th id="T_59d93_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_59d93_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_59d93_row5_col1" class="data row5 col1" >(2211, 166)</td>
#     </tr>
#     <tr>
#       <th id="T_59d93_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_59d93_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_59d93_row6_col1" class="data row6 col1" >(2211, 166)</td>
#     </tr>
#     <tr>
#       <th id="T_59d93_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_59d93_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_59d93_row7_col1" class="data row7 col1" >165</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_1d960 th {
#   text-align: left;
# }
# #T_1d960_row0_col0, #T_1d960_row1_col0, #T_1d960_row1_col1, #T_1d960_row1_col2, #T_1d960_row1_col3, #T_1d960_row1_col4, #T_1d960_row1_col5, #T_1d960_row1_col6, #T_1d960_row2_col0, #T_1d960_row2_col1, #T_1d960_row2_col2, #T_1d960_row2_col3, #T_1d960_row2_col4, #T_1d960_row2_col5, #T_1d960_row2_col6, #T_1d960_row3_col0, #T_1d960_row3_col1, #T_1d960_row3_col2, #T_1d960_row3_col3, #T_1d960_row3_col4, #T_1d960_row3_col5, #T_1d960_row3_col6, #T_1d960_row4_col0, #T_1d960_row4_col1, #T_1d960_row4_col2, #T_1d960_row4_col3, #T_1d960_row4_col4, #T_1d960_row4_col5, #T_1d960_row4_col6, #T_1d960_row5_col0, #T_1d960_row5_col1, #T_1d960_row5_col2, #T_1d960_row5_col3, #T_1d960_row5_col4, #T_1d960_row5_col5, #T_1d960_row5_col6, #T_1d960_row6_col0, #T_1d960_row6_col1, #T_1d960_row6_col2, #T_1d960_row6_col3, #T_1d960_row6_col4, #T_1d960_row6_col5, #T_1d960_row6_col6, #T_1d960_row7_col0, #T_1d960_row7_col1, #T_1d960_row7_col2, #T_1d960_row7_col3, #T_1d960_row7_col4, #T_1d960_row7_col5, #T_1d960_row7_col6, #T_1d960_row8_col0, #T_1d960_row8_col1, #T_1d960_row8_col2, #T_1d960_row8_col3, #T_1d960_row8_col4, #T_1d960_row8_col5, #T_1d960_row8_col6, #T_1d960_row9_col0, #T_1d960_row9_col1, #T_1d960_row9_col2, #T_1d960_row9_col3, #T_1d960_row9_col4, #T_1d960_row9_col5, #T_1d960_row9_col6, #T_1d960_row10_col0, #T_1d960_row10_col1, #T_1d960_row10_col2, #T_1d960_row10_col3, #T_1d960_row10_col4, #T_1d960_row10_col5, #T_1d960_row10_col6, #T_1d960_row11_col0, #T_1d960_row11_col1, #T_1d960_row11_col2, #T_1d960_row11_col3, #T_1d960_row11_col4, #T_1d960_row11_col5, #T_1d960_row11_col6, #T_1d960_row12_col0, #T_1d960_row12_col1, #T_1d960_row12_col2, #T_1d960_row12_col3, #T_1d960_row12_col4, #T_1d960_row12_col5, #T_1d960_row12_col6, #T_1d960_row13_col0, #T_1d960_row13_col1, #T_1d960_row13_col2, #T_1d960_row13_col3, #T_1d960_row13_col4, #T_1d960_row13_col5, #T_1d960_row13_col6, #T_1d960_row14_col0, #T_1d960_row14_col1, #T_1d960_row14_col2, #T_1d960_row14_col3, #T_1d960_row14_col4, #T_1d960_row14_col5, #T_1d960_row14_col6, #T_1d960_row15_col0, #T_1d960_row15_col1, #T_1d960_row15_col2, #T_1d960_row15_col3, #T_1d960_row15_col4, #T_1d960_row15_col5, #T_1d960_row15_col6, #T_1d960_row16_col0, #T_1d960_row16_col1, #T_1d960_row16_col2, #T_1d960_row16_col3, #T_1d960_row16_col4, #T_1d960_row16_col5, #T_1d960_row16_col6, #T_1d960_row17_col0, #T_1d960_row17_col1, #T_1d960_row17_col2, #T_1d960_row17_col3, #T_1d960_row17_col4, #T_1d960_row17_col5, #T_1d960_row17_col6, #T_1d960_row18_col0, #T_1d960_row18_col1, #T_1d960_row18_col2, #T_1d960_row18_col3, #T_1d960_row18_col4, #T_1d960_row18_col5, #T_1d960_row18_col6 {
#   text-align: left;
# }
# #T_1d960_row0_col1, #T_1d960_row0_col2, #T_1d960_row0_col3, #T_1d960_row0_col4, #T_1d960_row0_col5, #T_1d960_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_1d960_row0_col7, #T_1d960_row1_col7, #T_1d960_row2_col7, #T_1d960_row3_col7, #T_1d960_row4_col7, #T_1d960_row5_col7, #T_1d960_row6_col7, #T_1d960_row7_col7, #T_1d960_row8_col7, #T_1d960_row9_col7, #T_1d960_row10_col7, #T_1d960_row11_col7, #T_1d960_row16_col7, #T_1d960_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_1d960_row12_col7, #T_1d960_row13_col7, #T_1d960_row14_col7, #T_1d960_row15_col7, #T_1d960_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_1d960">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1d960_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1d960_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_1d960_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_1d960_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_1d960_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_1d960_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_1d960_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_1d960_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d960_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_1d960_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_1d960_row0_col1" class="data row0 col1" >0.3070</td>
#       <td id="T_1d960_row0_col2" class="data row0 col2" >0.1664</td>
#       <td id="T_1d960_row0_col3" class="data row0 col3" >0.4065</td>
#       <td id="T_1d960_row0_col4" class="data row0 col4" >0.8704</td>
#       <td id="T_1d960_row0_col5" class="data row0 col5" >0.1599</td>
#       <td id="T_1d960_row0_col6" class="data row0 col6" >0.1586</td>
#       <td id="T_1d960_row0_col7" class="data row0 col7" >0.5960</td>
#     </tr>
#     <tr>
#       <th id="T_1d960_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_1d960_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_1d960_row1_col1" class="data row1 col1" >0.3215</td>
#       <td id="T_1d960_row1_col2" class="data row1 col2" >0.1809</td>
#       <td id="T_1d960_row1_col3" class="data row1 col3" >0.4240</td>
#       <td id="T_1d960_row1_col4" class="data row1 col4" >0.8593</td>
#       <td id="T_1d960_row1_col5" class="data row1 col5" >0.1633</td>
#       <td id="T_1d960_row1_col6" class="data row1 col6" >0.1684</td>
#       <td id="T_1d960_row1_col7" class="data row1 col7" >0.0280</td>
#     </tr>
#     <tr>
#       <th id="T_1d960_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_1d960_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_1d960_row2_col1" class="data row2 col1" >0.3305</td>
#       <td id="T_1d960_row2_col2" class="data row2 col2" >0.1853</td>
#       <td id="T_1d960_row2_col3" class="data row2 col3" >0.4298</td>
#       <td id="T_1d960_row2_col4" class="data row2 col4" >0.8558</td>
#       <td id="T_1d960_row2_col5" class="data row2 col5" >0.1668</td>
#       <td id="T_1d960_row2_col6" class="data row2 col6" >0.1741</td>
#       <td id="T_1d960_row2_col7" class="data row2 col7" >0.2560</td>
#     </tr>
#     <tr>
#       <th id="T_1d960_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_1d960_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_1d960_row3_col1" class="data row3 col1" >0.3327</td>
#       <td id="T_1d960_row3_col2" class="data row3 col2" >0.1945</td>
#       <td id="T_1d960_row3_col3" class="data row3 col3" >0.4400</td>
#       <td id="T_1d960_row3_col4" class="data row3 col4" >0.8487</td>
#       <td id="T_1d960_row3_col5" class="data row3 col5" >0.1685</td>
#       <td id="T_1d960_row3_col6" class="data row3 col6" >0.1730</td>
#       <td id="T_1d960_row3_col7" class="data row3 col7" >0.1360</td>
#     </tr>
#     <tr>
#       <th id="T_1d960_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_1d960_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_1d960_row4_col1" class="data row4 col1" >0.3334</td>
#       <td id="T_1d960_row4_col2" class="data row4 col2" >0.1965</td>
#       <td id="T_1d960_row4_col3" class="data row4 col3" >0.4421</td>
#       <td id="T_1d960_row4_col4" class="data row4 col4" >0.8472</td>
#       <td id="T_1d960_row4_col5" class="data row4 col5" >0.1727</td>
#       <td id="T_1d960_row4_col6" class="data row4 col6" >0.1757</td>
#       <td id="T_1d960_row4_col7" class="data row4 col7" >0.2320</td>
#     </tr>
#     <tr>
#       <th id="T_1d960_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_1d960_row5_col0" class="data row5 col0" >Random Forest Regressor</td>
#       <td id="T_1d960_row5_col1" class="data row5 col1" >0.3493</td>
#       <td id="T_1d960_row5_col2" class="data row5 col2" >0.2226</td>
#       <td id="T_1d960_row5_col3" class="data row5 col3" >0.4701</td>
#       <td id="T_1d960_row5_col4" class="data row5 col4" >0.8267</td>
#       <td id="T_1d960_row5_col5" class="data row5 col5" >0.1853</td>
#       <

# %%
for i in best_model_2:
    print("Model Type: ", i)
    print("Hyperparamters: ", i.get_params())
    print("+++++++++++++++++++++++++++++++++")
# Out:
# Model Type:  <catboost.core.CatBoostRegressor object at 0x152dde0a0>
# Hyperparamters:  {'loss_function': 'RMSE', 'border_count': 254, 'verbose': False, 'task_type': 'CPU', 'random_state': 0}
# +++++++++++++++++++++++++++++++++
# Model Type:  LGBMRegressor(random_state=0)
# Hyperparamters:  {'boosting_type': 'gbdt', 'class_weight': None, 'colsample_bytree': 1.0, 'importance_type': 'split', 'learning_rate': 0.1, 'max_depth': -1, 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'n_estimators': 100, 'n_jobs': -1, 'num_leaves': 31, 'objective': None, 'random_state': 0, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': 'warn', 'subsample': 1.0, 'subsample_for_bin': 200000, 'subsample_freq': 0}
# +++++++++++++++++++++++++++++++++
# Model Type:  ExtraTreesRegressor(n_jobs=-1, random_state=0)
# Hyperparamters:  {'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_jobs': -1, 'oob_score': False, 'random_state': 0, 'verbose': 0, 'warm_start': False}
# +++++++++++++++++++++++++++++++++

# %% [markdown]
# ### **Type 3: Standardized, Sales Unchanged**

# %%
#train_data_s, test_data_s = train_test_split(data_s, test_size=0.2, random_state=42, shuffle=True)

kf = KFold(n_splits=5)

setup_3 = setup(data = data_s, test_data = data_s, target = 'sales', 
                fold_strategy = kf, transform_target = False, preprocess=False, data_split_shuffle = True,
                session_id = 0)

best_model_3 = compare_models(exclude = ["lar"], n_select = 3)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6f00f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f00f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6f00f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f00f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6f00f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6f00f_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6f00f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6f00f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6f00f_row1_col1" class="data row1 col1" >sales</td>
#     </tr>
#     <tr>
#       <th id="T_6f00f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6f00f_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_6f00f_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_6f00f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6f00f_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_6f00f_row3_col1" class="data row3 col1" >(4422, 166)</td>
#     </tr>
#     <tr>
#       <th id="T_6f00f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6f00f_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_6f00f_row4_col1" class="data row4 col1" >(4422, 166)</td>
#     </tr>
#     <tr>
#       <th id="T_6f00f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6f00f_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_6f00f_row5_col1" class="data row5 col1" >(2211, 166)</td>
#     </tr>
#     <tr>
#       <th id="T_6f00f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6f00f_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_6f00f_row6_col1" class="data row6 col1" >(2211, 166)</td>
#     </tr>
#     <tr>
#       <th id="T_6f00f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6f00f_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_6f00f_row7_col1" class="data row7 col1" >165</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_df386 th {
#   text-align: left;
# }
# #T_df386_row0_col0, #T_df386_row1_col0, #T_df386_row1_col1, #T_df386_row1_col2, #T_df386_row1_col3, #T_df386_row1_col4, #T_df386_row1_col5, #T_df386_row1_col6, #T_df386_row2_col0, #T_df386_row2_col1, #T_df386_row2_col2, #T_df386_row2_col3, #T_df386_row2_col4, #T_df386_row2_col5, #T_df386_row2_col6, #T_df386_row3_col0, #T_df386_row3_col1, #T_df386_row3_col2, #T_df386_row3_col3, #T_df386_row3_col4, #T_df386_row3_col5, #T_df386_row3_col6, #T_df386_row4_col0, #T_df386_row4_col1, #T_df386_row4_col2, #T_df386_row4_col3, #T_df386_row4_col4, #T_df386_row4_col5, #T_df386_row4_col6, #T_df386_row5_col0, #T_df386_row5_col1, #T_df386_row5_col2, #T_df386_row5_col3, #T_df386_row5_col4, #T_df386_row5_col5, #T_df386_row5_col6, #T_df386_row6_col0, #T_df386_row6_col1, #T_df386_row6_col2, #T_df386_row6_col3, #T_df386_row6_col4, #T_df386_row6_col5, #T_df386_row6_col6, #T_df386_row7_col0, #T_df386_row7_col1, #T_df386_row7_col2, #T_df386_row7_col3, #T_df386_row7_col4, #T_df386_row7_col5, #T_df386_row7_col6, #T_df386_row8_col0, #T_df386_row8_col1, #T_df386_row8_col2, #T_df386_row8_col3, #T_df386_row8_col4, #T_df386_row8_col5, #T_df386_row8_col6, #T_df386_row9_col0, #T_df386_row9_col1, #T_df386_row9_col2, #T_df386_row9_col3, #T_df386_row9_col4, #T_df386_row9_col5, #T_df386_row9_col6, #T_df386_row10_col0, #T_df386_row10_col1, #T_df386_row10_col2, #T_df386_row10_col3, #T_df386_row10_col4, #T_df386_row10_col5, #T_df386_row10_col6, #T_df386_row11_col0, #T_df386_row11_col1, #T_df386_row11_col2, #T_df386_row11_col3, #T_df386_row11_col4, #T_df386_row11_col5, #T_df386_row11_col6, #T_df386_row12_col0, #T_df386_row12_col1, #T_df386_row12_col2, #T_df386_row12_col3, #T_df386_row12_col4, #T_df386_row12_col5, #T_df386_row12_col6, #T_df386_row13_col0, #T_df386_row13_col1, #T_df386_row13_col2, #T_df386_row13_col3, #T_df386_row13_col4, #T_df386_row13_col5, #T_df386_row13_col6, #T_df386_row14_col0, #T_df386_row14_col1, #T_df386_row14_col2, #T_df386_row14_col3, #T_df386_row14_col4, #T_df386_row14_col5, #T_df386_row14_col6, #T_df386_row15_col0, #T_df386_row15_col1, #T_df386_row15_col2, #T_df386_row15_col3, #T_df386_row15_col4, #T_df386_row15_col5, #T_df386_row15_col6, #T_df386_row16_col0, #T_df386_row16_col1, #T_df386_row16_col2, #T_df386_row16_col3, #T_df386_row16_col4, #T_df386_row16_col5, #T_df386_row16_col6, #T_df386_row17_col0, #T_df386_row17_col1, #T_df386_row17_col2, #T_df386_row17_col3, #T_df386_row17_col4, #T_df386_row17_col5, #T_df386_row17_col6, #T_df386_row18_col0, #T_df386_row18_col1, #T_df386_row18_col2, #T_df386_row18_col3, #T_df386_row18_col4, #T_df386_row18_col5, #T_df386_row18_col6 {
#   text-align: left;
# }
# #T_df386_row0_col1, #T_df386_row0_col2, #T_df386_row0_col3, #T_df386_row0_col4, #T_df386_row0_col5, #T_df386_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_df386_row0_col7, #T_df386_row1_col7, #T_df386_row2_col7, #T_df386_row3_col7, #T_df386_row4_col7, #T_df386_row5_col7, #T_df386_row7_col7, #T_df386_row8_col7, #T_df386_row9_col7, #T_df386_row10_col7, #T_df386_row11_col7, #T_df386_row12_col7, #T_df386_row13_col7, #T_df386_row14_col7, #T_df386_row15_col7, #T_df386_row16_col7, #T_df386_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_df386_row6_col7, #T_df386_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_df386">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df386_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_df386_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_df386_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_df386_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_df386_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_df386_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_df386_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_df386_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df386_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_df386_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_df386_row0_col1" class="data row0 col1" >6.2046</td>
#       <td id="T_df386_row0_col2" class="data row0 col2" >246.1771</td>
#       <td id="T_df386_row0_col3" class="data row0 col3" >15.3094</td>
#       <td id="T_df386_row0_col4" class="data row0 col4" >0.6832</td>
#       <td id="T_df386_row0_col5" class="data row0 col5" >0.4556</td>
#       <td id="T_df386_row0_col6" class="data row0 col6" >0.5640</td>
#       <td id="T_df386_row0_col7" class="data row0 col7" >0.5560</td>
#     </tr>
#     <tr>
#       <th id="T_df386_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_df386_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_df386_row1_col1" class="data row1 col1" >6.4866</td>
#       <td id="T_df386_row1_col2" class="data row1 col2" >269.5358</td>
#       <td id="T_df386_row1_col3" class="data row1 col3" >16.0685</td>
#       <td id="T_df386_row1_col4" class="data row1 col4" >0.6534</td>
#       <td id="T_df386_row1_col5" class="data row1 col5" >0.4601</td>
#       <td id="T_df386_row1_col6" class="data row1 col6" >0.6195</td>
#       <td id="T_df386_row1_col7" class="data row1 col7" >0.3020</td>
#     </tr>
#     <tr>
#       <th id="T_df386_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_df386_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_df386_row2_col1" class="data row2 col1" >6.7842</td>
#       <td id="T_df386_row2_col2" class="data row2 col2" >276.2141</td>
#       <td id="T_df386_row2_col3" class="data row2 col3" >16.1384</td>
#       <td id="T_df386_row2_col4" class="data row2 col4" >0.6441</td>
#       <td id="T_df386_row2_col5" class="data row2 col5" >0.4854</td>
#       <td id="T_df386_row2_col6" class="data row2 col6" >0.6894</td>
#       <td id="T_df386_row2_col7" class="data row2 col7" >0.3020</td>
#     </tr>
#     <tr>
#       <th id="T_df386_level0_row3" class="row_heading level0 row3" >xgboost</th>
#       <td id="T_df386_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_df386_row3_col1" class="data row3 col1" >6.6722</td>
#       <td id="T_df386_row3_col2" class="data row3 col2" >277.7497</td>
#       <td id="T_df386_row3_col3" class="data row3 col3" >16.3616</td>
#       <td id="T_df386_row3_col4" class="data row3 col4" >0.6381</td>
#       <td id="T_df386_row3_col5" class="data row3 col5" >0.4814</td>
#       <td id="T_df386_row3_col6" class="data row3 col6" >0.6317</td>
#       <td id="T_df386_row3_col7" class="data row3 col7" >0.2540</td>
#     </tr>
#     <tr>
#       <th id="T_df386_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_df386_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_df386_row4_col1" class="data row4 col1" >6.9208</td>
#       <td id="T_df386_row4_col2" class="data row4 col2" >283.2277</td>
#       <td id="T_df386_row4_col3" class="data row4 col3" >16.3957</td>
#       <td id="T_df386_row4_col4" class="data row4 col4" >0.6354</td>
#       <td id="T_df386_row4_col5" class="data row4 col5" >0.5194</td>
#       <td id="T_df386_row4_col6" class="data row4 col6" >0.7147</td>
#       <td id="T_df386_row4_col7" class="data row4 col7" >0.1600</td>
#     </tr>
#     <tr>
#       <th id="T_df386_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_df386_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_df386_row5_col1" class="data row5 col1" >6.8590</td>
#       <td id="T_df386_row5_col2" class="data row5 col2" >290.4653</td>
#       <td id="T_df386_row5_col3" class="data row5 col3" >16.6879</td>
#       <td id="T_df386_row5_col4" class="data row5 col4" >0.6222</td>
#       <td id="T_df386_row5_col5" class="data row5 col5" >0

# %%
## Parameters
for i in best_model_3:
    print("Model Type: ", i)
    print("Hyperparamters: ", i.get_params())
    print("+++++++++++++++++++++++++++++++++")
# Out:
# Model Type:  <catboost.core.CatBoostRegressor object at 0x154587e50>
# Hyperparamters:  {'loss_function': 'RMSE', 'border_count': 254, 'verbose': False, 'task_type': 'CPU', 'random_state': 0}
# +++++++++++++++++++++++++++++++++
# Model Type:  ExtraTreesRegressor(n_jobs=-1, random_state=0)
# Hyperparamters:  {'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_jobs': -1, 'oob_score': False, 'random_state': 0, 'verbose': 0, 'warm_start': False}
# +++++++++++++++++++++++++++++++++
# Model Type:  RandomForestRegressor(n_jobs=-1, random_state=0)
# Hyperparamters:  {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_jobs': -1, 'oob_score': False, 'random_state': 0, 'verbose': 0, 'warm_start': False}
# +++++++++++++++++++++++++++++++++

# %% [markdown]
# ### **Type 4: Standardized, Log Sales**

# %%
#train_data_sl, test_data_sl = train_test_split(data_sl, test_size=0.2, random_state=42, shuffle=True)

kf = KFold(n_splits=5)

setup_4 = setup(data = data_sl, test_data = data_sl, target = 'sales', 
                fold_strategy = kf, transform_target = False, preprocess=False, data_split_shuffle = True,
                session_id = 0)

best_model_4 = compare_models(exclude = ["lar"], n_select = 3)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ae2e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae2e6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ae2e6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae2e6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ae2e6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ae2e6_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ae2e6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ae2e6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ae2e6_row1_col1" class="data row1 col1" >sales</td>
#     </tr>
#     <tr>
#       <th id="T_ae2e6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ae2e6_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_ae2e6_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_ae2e6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ae2e6_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_ae2e6_row3_col1" class="data row3 col1" >(4422, 166)</td>
#     </tr>
#     <tr>
#       <th id="T_ae2e6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ae2e6_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_ae2e6_row4_col1" class="data row4 col1" >(4422, 166)</td>
#     </tr>
#     <tr>
#       <th id="T_ae2e6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ae2e6_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_ae2e6_row5_col1" class="data row5 col1" >(2211, 166)</td>
#     </tr>
#     <tr>
#       <th id="T_ae2e6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ae2e6_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_ae2e6_row6_col1" class="data row6 col1" >(2211, 166)</td>
#     </tr>
#     <tr>
#       <th id="T_ae2e6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ae2e6_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_ae2e6_row7_col1" class="data row7 col1" >165</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7c9db th {
#   text-align: left;
# }
# #T_7c9db_row0_col0, #T_7c9db_row1_col0, #T_7c9db_row1_col1, #T_7c9db_row1_col2, #T_7c9db_row1_col3, #T_7c9db_row1_col4, #T_7c9db_row1_col5, #T_7c9db_row1_col6, #T_7c9db_row2_col0, #T_7c9db_row2_col1, #T_7c9db_row2_col2, #T_7c9db_row2_col3, #T_7c9db_row2_col4, #T_7c9db_row2_col5, #T_7c9db_row2_col6, #T_7c9db_row3_col0, #T_7c9db_row3_col1, #T_7c9db_row3_col2, #T_7c9db_row3_col3, #T_7c9db_row3_col4, #T_7c9db_row3_col5, #T_7c9db_row3_col6, #T_7c9db_row4_col0, #T_7c9db_row4_col1, #T_7c9db_row4_col2, #T_7c9db_row4_col3, #T_7c9db_row4_col4, #T_7c9db_row4_col5, #T_7c9db_row4_col6, #T_7c9db_row5_col0, #T_7c9db_row5_col1, #T_7c9db_row5_col2, #T_7c9db_row5_col3, #T_7c9db_row5_col4, #T_7c9db_row5_col5, #T_7c9db_row5_col6, #T_7c9db_row6_col0, #T_7c9db_row6_col1, #T_7c9db_row6_col2, #T_7c9db_row6_col3, #T_7c9db_row6_col4, #T_7c9db_row6_col5, #T_7c9db_row6_col6, #T_7c9db_row7_col0, #T_7c9db_row7_col1, #T_7c9db_row7_col2, #T_7c9db_row7_col3, #T_7c9db_row7_col4, #T_7c9db_row7_col5, #T_7c9db_row7_col6, #T_7c9db_row8_col0, #T_7c9db_row8_col1, #T_7c9db_row8_col2, #T_7c9db_row8_col3, #T_7c9db_row8_col4, #T_7c9db_row8_col5, #T_7c9db_row8_col6, #T_7c9db_row9_col0, #T_7c9db_row9_col1, #T_7c9db_row9_col2, #T_7c9db_row9_col3, #T_7c9db_row9_col4, #T_7c9db_row9_col5, #T_7c9db_row9_col6, #T_7c9db_row10_col0, #T_7c9db_row10_col1, #T_7c9db_row10_col2, #T_7c9db_row10_col3, #T_7c9db_row10_col4, #T_7c9db_row10_col5, #T_7c9db_row10_col6, #T_7c9db_row11_col0, #T_7c9db_row11_col1, #T_7c9db_row11_col2, #T_7c9db_row11_col3, #T_7c9db_row11_col4, #T_7c9db_row11_col5, #T_7c9db_row11_col6, #T_7c9db_row12_col0, #T_7c9db_row12_col1, #T_7c9db_row12_col2, #T_7c9db_row12_col3, #T_7c9db_row12_col4, #T_7c9db_row12_col5, #T_7c9db_row12_col6, #T_7c9db_row13_col0, #T_7c9db_row13_col1, #T_7c9db_row13_col2, #T_7c9db_row13_col3, #T_7c9db_row13_col4, #T_7c9db_row13_col5, #T_7c9db_row13_col6, #T_7c9db_row14_col0, #T_7c9db_row14_col1, #T_7c9db_row14_col2, #T_7c9db_row14_col3, #T_7c9db_row14_col4, #T_7c9db_row14_col5, #T_7c9db_row14_col6, #T_7c9db_row15_col0, #T_7c9db_row15_col1, #T_7c9db_row15_col2, #T_7c9db_row15_col3, #T_7c9db_row15_col4, #T_7c9db_row15_col5, #T_7c9db_row15_col6, #T_7c9db_row16_col0, #T_7c9db_row16_col1, #T_7c9db_row16_col2, #T_7c9db_row16_col3, #T_7c9db_row16_col4, #T_7c9db_row16_col5, #T_7c9db_row16_col6, #T_7c9db_row17_col0, #T_7c9db_row17_col1, #T_7c9db_row17_col2, #T_7c9db_row17_col3, #T_7c9db_row17_col4, #T_7c9db_row17_col5, #T_7c9db_row17_col6, #T_7c9db_row18_col0, #T_7c9db_row18_col1, #T_7c9db_row18_col2, #T_7c9db_row18_col3, #T_7c9db_row18_col4, #T_7c9db_row18_col5, #T_7c9db_row18_col6 {
#   text-align: left;
# }
# #T_7c9db_row0_col1, #T_7c9db_row0_col2, #T_7c9db_row0_col3, #T_7c9db_row0_col4, #T_7c9db_row0_col5, #T_7c9db_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_7c9db_row0_col7, #T_7c9db_row1_col7, #T_7c9db_row2_col7, #T_7c9db_row3_col7, #T_7c9db_row4_col7, #T_7c9db_row5_col7, #T_7c9db_row6_col7, #T_7c9db_row7_col7, #T_7c9db_row8_col7, #T_7c9db_row9_col7, #T_7c9db_row10_col7, #T_7c9db_row11_col7, #T_7c9db_row12_col7, #T_7c9db_row14_col7, #T_7c9db_row15_col7, #T_7c9db_row16_col7, #T_7c9db_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_7c9db_row13_col7, #T_7c9db_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_7c9db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c9db_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7c9db_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_7c9db_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_7c9db_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_7c9db_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_7c9db_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_7c9db_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_7c9db_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c9db_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_7c9db_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_7c9db_row0_col1" class="data row0 col1" >0.3070</td>
#       <td id="T_7c9db_row0_col2" class="data row0 col2" >0.1664</td>
#       <td id="T_7c9db_row0_col3" class="data row0 col3" >0.4064</td>
#       <td id="T_7c9db_row0_col4" class="data row0 col4" >0.8704</td>
#       <td id="T_7c9db_row0_col5" class="data row0 col5" >0.1599</td>
#       <td id="T_7c9db_row0_col6" class="data row0 col6" >0.1586</td>
#       <td id="T_7c9db_row0_col7" class="data row0 col7" >0.0340</td>
#     </tr>
#     <tr>
#       <th id="T_7c9db_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_7c9db_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_7c9db_row1_col1" class="data row1 col1" >0.3215</td>
#       <td id="T_7c9db_row1_col2" class="data row1 col2" >0.1810</td>
#       <td id="T_7c9db_row1_col3" class="data row1 col3" >0.4241</td>
#       <td id="T_7c9db_row1_col4" class="data row1 col4" >0.8592</td>
#       <td id="T_7c9db_row1_col5" class="data row1 col5" >0.1633</td>
#       <td id="T_7c9db_row1_col6" class="data row1 col6" >0.1684</td>
#       <td id="T_7c9db_row1_col7" class="data row1 col7" >0.0500</td>
#     </tr>
#     <tr>
#       <th id="T_7c9db_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_7c9db_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_7c9db_row2_col1" class="data row2 col1" >0.3305</td>
#       <td id="T_7c9db_row2_col2" class="data row2 col2" >0.1853</td>
#       <td id="T_7c9db_row2_col3" class="data row2 col3" >0.4298</td>
#       <td id="T_7c9db_row2_col4" class="data row2 col4" >0.8558</td>
#       <td id="T_7c9db_row2_col5" class="data row2 col5" >0.1668</td>
#       <td id="T_7c9db_row2_col6" class="data row2 col6" >0.1741</td>
#       <td id="T_7c9db_row2_col7" class="data row2 col7" >0.0500</td>
#     </tr>
#     <tr>
#       <th id="T_7c9db_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_7c9db_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_7c9db_row3_col1" class="data row3 col1" >0.3326</td>
#       <td id="T_7c9db_row3_col2" class="data row3 col2" >0.1945</td>
#       <td id="T_7c9db_row3_col3" class="data row3 col3" >0.4400</td>
#       <td id="T_7c9db_row3_col4" class="data row3 col4" >0.8488</td>
#       <td id="T_7c9db_row3_col5" class="data row3 col5" >0.1684</td>
#       <td id="T_7c9db_row3_col6" class="data row3 col6" >0.1730</td>
#       <td id="T_7c9db_row3_col7" class="data row3 col7" >0.0340</td>
#     </tr>
#     <tr>
#       <th id="T_7c9db_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_7c9db_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_7c9db_row4_col1" class="data row4 col1" >0.3333</td>
#       <td id="T_7c9db_row4_col2" class="data row4 col2" >0.1963</td>
#       <td id="T_7c9db_row4_col3" class="data row4 col3" >0.4418</td>
#       <td id="T_7c9db_row4_col4" class="data row4 col4" >0.8474</td>
#       <td id="T_7c9db_row4_col5" class="data row4 col5" >0.1727</td>
#       <td id="T_7c9db_row4_col6" class="data row4 col6" >0.1757</td>
#       <td id="T_7c9db_row4_col7" class="data row4 col7" >0.0300</td>
#     </tr>
#     <tr>
#       <th id="T_7c9db_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_7c9db_row5_col0" class="data row5 col0" >Random Forest Regressor</td>
#       <td id="T_7c9db_row5_col1" class="data row5 col1" >0.3495</td>
#       <td id="T_7c9db_row5_col2" class="data row5 col2" >0.2228</td>
#       <td id="T_7c9db_row5_col3" class="data row5 col3" >0.4703</td>
#       <td id="T_7c9db_row5_col4" class="data row5 col4" >0.8265</td>
#       <td id="T_7c9db_row5_col5" class="data row5 col5" >0.1854</td>
#       <

# %%
## Parameters
for i in best_model_4:
    print("Model Type: ", i)
    print("Hyperparamters: ", i.get_params())
    print("+++++++++++++++++++++++++++++++++")
# Out:
# Model Type:  <catboost.core.CatBoostRegressor object at 0x15238cdf0>
# Hyperparamters:  {'loss_function': 'RMSE', 'border_count': 254, 'verbose': False, 'task_type': 'CPU', 'random_state': 0}
# +++++++++++++++++++++++++++++++++
# Model Type:  LGBMRegressor(random_state=0)
# Hyperparamters:  {'boosting_type': 'gbdt', 'class_weight': None, 'colsample_bytree': 1.0, 'importance_type': 'split', 'learning_rate': 0.1, 'max_depth': -1, 'min_child_samples': 20, 'min_child_weight': 0.001, 'min_split_gain': 0.0, 'n_estimators': 100, 'n_jobs': -1, 'num_leaves': 31, 'objective': None, 'random_state': 0, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': 'warn', 'subsample': 1.0, 'subsample_for_bin': 200000, 'subsample_freq': 0}
# +++++++++++++++++++++++++++++++++
# Model Type:  ExtraTreesRegressor(n_jobs=-1, random_state=0)
# Hyperparamters:  {'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_jobs': -1, 'oob_score': False, 'random_state': 0, 'verbose': 0, 'warm_start': False}
# +++++++++++++++++++++++++++++++++

# %% [markdown]
# ### **Conduct Feature Selection**

# %%
kf = KFold(n_splits=5)

setup_2a = setup(data = data_l, test_data = data_l, target = 'sales', 
                 fold_strategy = kf, transform_target = False, preprocess=False, data_split_shuffle = True,
                 feature_selection=True,
                 session_id = 0)

best_model_2a = compare_models(exclude = ["lar"], n_select = 3)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8a4af">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a4af_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8a4af_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a4af_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8a4af_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_8a4af_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8a4af_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8a4af_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_8a4af_row1_col1" class="data row1 col1" >sales</td>
#     </tr>
#     <tr>
#       <th id="T_8a4af_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8a4af_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_8a4af_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_8a4af_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8a4af_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_8a4af_row3_col1" class="data row3 col1" >(4422, 166)</td>
#     </tr>
#     <tr>
#       <th id="T_8a4af_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8a4af_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_8a4af_row4_col1" class="data row4 col1" >(4422, 166)</td>
#     </tr>
#     <tr>
#       <th id="T_8a4af_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8a4af_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_8a4af_row5_col1" class="data row5 col1" >(2211, 166)</td>
#     </tr>
#     <tr>
#       <th id="T_8a4af_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8a4af_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_8a4af_row6_col1" class="data row6 col1" >(2211, 166)</td>
#     </tr>
#     <tr>
#       <th id="T_8a4af_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8a4af_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_8a4af_row7_col1" class="data row7 col1" >165</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_adbc7 th {
#   text-align: left;
# }
# #T_adbc7_row0_col0, #T_adbc7_row1_col0, #T_adbc7_row1_col1, #T_adbc7_row1_col2, #T_adbc7_row1_col3, #T_adbc7_row1_col4, #T_adbc7_row1_col5, #T_adbc7_row1_col6, #T_adbc7_row2_col0, #T_adbc7_row2_col1, #T_adbc7_row2_col2, #T_adbc7_row2_col3, #T_adbc7_row2_col4, #T_adbc7_row2_col5, #T_adbc7_row2_col6, #T_adbc7_row3_col0, #T_adbc7_row3_col1, #T_adbc7_row3_col2, #T_adbc7_row3_col3, #T_adbc7_row3_col4, #T_adbc7_row3_col5, #T_adbc7_row3_col6, #T_adbc7_row4_col0, #T_adbc7_row4_col1, #T_adbc7_row4_col2, #T_adbc7_row4_col3, #T_adbc7_row4_col4, #T_adbc7_row4_col5, #T_adbc7_row4_col6, #T_adbc7_row5_col0, #T_adbc7_row5_col1, #T_adbc7_row5_col2, #T_adbc7_row5_col3, #T_adbc7_row5_col4, #T_adbc7_row5_col5, #T_adbc7_row5_col6, #T_adbc7_row6_col0, #T_adbc7_row6_col1, #T_adbc7_row6_col2, #T_adbc7_row6_col3, #T_adbc7_row6_col4, #T_adbc7_row6_col5, #T_adbc7_row6_col6, #T_adbc7_row7_col0, #T_adbc7_row7_col1, #T_adbc7_row7_col2, #T_adbc7_row7_col3, #T_adbc7_row7_col4, #T_adbc7_row7_col5, #T_adbc7_row7_col6, #T_adbc7_row8_col0, #T_adbc7_row8_col1, #T_adbc7_row8_col2, #T_adbc7_row8_col3, #T_adbc7_row8_col4, #T_adbc7_row8_col5, #T_adbc7_row8_col6, #T_adbc7_row9_col0, #T_adbc7_row9_col1, #T_adbc7_row9_col2, #T_adbc7_row9_col3, #T_adbc7_row9_col4, #T_adbc7_row9_col5, #T_adbc7_row9_col6, #T_adbc7_row10_col0, #T_adbc7_row10_col1, #T_adbc7_row10_col2, #T_adbc7_row10_col3, #T_adbc7_row10_col4, #T_adbc7_row10_col5, #T_adbc7_row10_col6, #T_adbc7_row11_col0, #T_adbc7_row11_col1, #T_adbc7_row11_col2, #T_adbc7_row11_col3, #T_adbc7_row11_col4, #T_adbc7_row11_col5, #T_adbc7_row11_col6, #T_adbc7_row12_col0, #T_adbc7_row12_col1, #T_adbc7_row12_col2, #T_adbc7_row12_col3, #T_adbc7_row12_col4, #T_adbc7_row12_col5, #T_adbc7_row12_col6, #T_adbc7_row13_col0, #T_adbc7_row13_col1, #T_adbc7_row13_col2, #T_adbc7_row13_col3, #T_adbc7_row13_col4, #T_adbc7_row13_col5, #T_adbc7_row13_col6, #T_adbc7_row14_col0, #T_adbc7_row14_col1, #T_adbc7_row14_col2, #T_adbc7_row14_col3, #T_adbc7_row14_col4, #T_adbc7_row14_col5, #T_adbc7_row14_col6, #T_adbc7_row15_col0, #T_adbc7_row15_col1, #T_adbc7_row15_col2, #T_adbc7_row15_col3, #T_adbc7_row15_col4, #T_adbc7_row15_col5, #T_adbc7_row15_col6, #T_adbc7_row16_col0, #T_adbc7_row16_col1, #T_adbc7_row16_col2, #T_adbc7_row16_col3, #T_adbc7_row16_col4, #T_adbc7_row16_col5, #T_adbc7_row16_col6, #T_adbc7_row17_col0, #T_adbc7_row17_col1, #T_adbc7_row17_col2, #T_adbc7_row17_col3, #T_adbc7_row17_col4, #T_adbc7_row17_col5, #T_adbc7_row17_col6, #T_adbc7_row18_col0, #T_adbc7_row18_col1, #T_adbc7_row18_col2, #T_adbc7_row18_col3, #T_adbc7_row18_col4, #T_adbc7_row18_col5, #T_adbc7_row18_col6 {
#   text-align: left;
# }
# #T_adbc7_row0_col1, #T_adbc7_row0_col2, #T_adbc7_row0_col3, #T_adbc7_row0_col4, #T_adbc7_row0_col5, #T_adbc7_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_adbc7_row0_col7, #T_adbc7_row1_col7, #T_adbc7_row2_col7, #T_adbc7_row3_col7, #T_adbc7_row4_col7, #T_adbc7_row5_col7, #T_adbc7_row6_col7, #T_adbc7_row7_col7, #T_adbc7_row8_col7, #T_adbc7_row10_col7, #T_adbc7_row11_col7, #T_adbc7_row12_col7, #T_adbc7_row13_col7, #T_adbc7_row14_col7, #T_adbc7_row15_col7, #T_adbc7_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_adbc7_row9_col7, #T_adbc7_row16_col7, #T_adbc7_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_adbc7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_adbc7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_adbc7_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_adbc7_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_adbc7_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_adbc7_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_adbc7_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_adbc7_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_adbc7_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_adbc7_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_adbc7_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_adbc7_row0_col1" class="data row0 col1" >0.3070</td>
#       <td id="T_adbc7_row0_col2" class="data row0 col2" >0.1664</td>
#       <td id="T_adbc7_row0_col3" class="data row0 col3" >0.4065</td>
#       <td id="T_adbc7_row0_col4" class="data row0 col4" >0.8704</td>
#       <td id="T_adbc7_row0_col5" class="data row0 col5" >0.1599</td>
#       <td id="T_adbc7_row0_col6" class="data row0 col6" >0.1586</td>
#       <td id="T_adbc7_row0_col7" class="data row0 col7" >0.0140</td>
#     </tr>
#     <tr>
#       <th id="T_adbc7_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_adbc7_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_adbc7_row1_col1" class="data row1 col1" >0.3215</td>
#       <td id="T_adbc7_row1_col2" class="data row1 col2" >0.1809</td>
#       <td id="T_adbc7_row1_col3" class="data row1 col3" >0.4240</td>
#       <td id="T_adbc7_row1_col4" class="data row1 col4" >0.8593</td>
#       <td id="T_adbc7_row1_col5" class="data row1 col5" >0.1633</td>
#       <td id="T_adbc7_row1_col6" class="data row1 col6" >0.1684</td>
#       <td id="T_adbc7_row1_col7" class="data row1 col7" >0.0260</td>
#     </tr>
#     <tr>
#       <th id="T_adbc7_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_adbc7_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_adbc7_row2_col1" class="data row2 col1" >0.3305</td>
#       <td id="T_adbc7_row2_col2" class="data row2 col2" >0.1853</td>
#       <td id="T_adbc7_row2_col3" class="data row2 col3" >0.4298</td>
#       <td id="T_adbc7_row2_col4" class="data row2 col4" >0.8558</td>
#       <td id="T_adbc7_row2_col5" class="data row2 col5" >0.1668</td>
#       <td id="T_adbc7_row2_col6" class="data row2 col6" >0.1741</td>
#       <td id="T_adbc7_row2_col7" class="data row2 col7" >0.0260</td>
#     </tr>
#     <tr>
#       <th id="T_adbc7_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_adbc7_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_adbc7_row3_col1" class="data row3 col1" >0.3327</td>
#       <td id="T_adbc7_row3_col2" class="data row3 col2" >0.1945</td>
#       <td id="T_adbc7_row3_col3" class="data row3 col3" >0.4400</td>
#       <td id="T_adbc7_row3_col4" class="data row3 col4" >0.8487</td>
#       <td id="T_adbc7_row3_col5" class="data row3 col5" >0.1685</td>
#       <td id="T_adbc7_row3_col6" class="data row3 col6" >0.1730</td>
#       <td id="T_adbc7_row3_col7" class="data row3 col7" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_adbc7_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_adbc7_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_adbc7_row4_col1" class="data row4 col1" >0.3334</td>
#       <td id="T_adbc7_row4_col2" class="data row4 col2" >0.1965</td>
#       <td id="T_adbc7_row4_col3" class="data row4 col3" >0.4421</td>
#       <td id="T_adbc7_row4_col4" class="data row4 col4" >0.8472</td>
#       <td id="T_adbc7_row4_col5" class="data row4 col5" >0.1727</td>
#       <td id="T_adbc7_row4_col6" class="data row4 col6" >0.1757</td>
#       <td id="T_adbc7_row4_col7" class="data row4 col7" >0.0080</td>
#     </tr>
#     <tr>
#       <th id="T_adbc7_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_adbc7_row5_col0" class="data row5 col0" >Random Forest Regressor</td>
#       <td id="T_adbc7_row5_col1" class="data row5 col1" >0.3493</td>
#       <td id="T_adbc7_row5_col2" class="data row5 col2" >0.2226</td>
#       <td id="T_adbc7_row5_col3" class="data row5 col3" >0.4701</td>
#       <td id="T_adbc7_row5_col4" class="data row5 col4" >0.8267</td>
#       <td id="T_adbc7_row5_col5" class="data row5 col5" >0.1853</td>
#       <
